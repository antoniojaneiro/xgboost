# %% [markdown]
# # XGBoost

# %% [markdown]
# ### XGBoost Overview
#
# **XGBoost** (eXtreme Gradient Boosting) is a machine learning algorithm that is efficient and scalable for tasks like classification and regression. It is an implementation of gradient-boosted decision trees designed for high performance.
#
# #### Key Features
# - **Gradient Boosting**: Sequentially builds models to correct errors of previous ones.
# - **Regularization**: L1 and L2 regularization to prevent overfitting.
# - **Missing Values**: Handles missing data internally.
# - **Parallel Processing**: Optimized for speed using hardware resources.
# - **Tree Pruning**: Uses depth-first approach to prune trees.
#
# #### How XGBoost Works
# 1. **Initialization**: Start with an initial prediction (e.g., mean for regression).
# 2. **Residuals**: Compute the error (residuals).
# 3. **Fit Tree**: Fit a decision tree to the residuals.
# 4. **Update**: Update the prediction by adding the new tree.
# 5. **Repeat**: Continue until error is minimized.
#
# #### Important Parameters
# - **Learning Rate (eta)**: Controls contribution of each tree.
# - **Max Depth (max_depth)**: Maximum depth of each tree.
# - **Subsample**: Fraction of data used per tree.
# - **Colsample_bytree**: Fraction of features used per tree.
# - **n_estimators**: Number of boosting rounds.
#
# #### Objective Function
#
# The model minimizes the following objective function:
#
# $$
# \text{Obj} = \sum_{i=1}^{n} L(y_i, \hat{y}_i^{(t)}) + \sum_{t=1}^{T} \Omega(f_t)
# $$
#
# Where the first part is the loss function, and the second part is the regularization term.

# %% [markdown]
# ### Introduction
#
# We will be solving this exercise using a hand-made grid-search hyperparameter tuning, this gives us the freedom of using xgboost package functions. I find it particularly important because using xgb's own package instead of sklearn we can use more xgb tools such as early stopping!
#
# Lets start with our exercise! We will be training a XGBoost Classifier to try to predict whether a certain individual had an income of greater than 50,000 based on their demographic information.

# %% [markdown]
# # 1. Load Data

# %%
# !pip install numpy == 1.26.4
# !pip install pandas == 2.2.1
# !pip install xgboost == 2.1.1
# !pip install seaborn == 0.13.2
# !pip install matplotlib == 3.8.3
# Out:
# ERROR: Invalid requirement: '=='
# ERROR: Invalid requirement: '=='
# ERROR: Invalid requirement: '=='
# ERROR: Invalid requirement: '=='
# ERROR: Invalid requirement: '=='

# %%
import numpy as np
import pandas as pd

# %%
train_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header = None)
test_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test', skiprows = 1, header = None) # Make sure to skip a row for the test set

# %%
train_set.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
test_set.head()
# Out:
#    0           1       2              3   4                    5   \
# 0  25     Private  226802           11th   7        Never-married
# 1  38     Private   89814        HS-grad   9   Married-civ-spouse
# 2  28   Local-gov  336951     Assoc-acdm  12   Married-civ-spouse
# 3  44     Private  160323   Some-college  10   Married-civ-spouse
# 4  18           ?  103497   Some-college  10        Never-married
#
#                    6           7       8        9     10  11  12  \
# 0   Machine-op-inspct   Own-child   Black     Male     0   0  40
# 1     Farming-fishing     Husband   White     Male     0   0  50
# 2     Protective-serv     Husband   White     Male     0   0  40
# 3   Machine-op-inspct     Husband   Black     Male  7688   0  40
# 4                   ?   Own-child   White   Female     0   0  30
#
#                13       14
# 0   United-States   <=50K.
# 1   United-States   <=50K.
# 2   United-States    >50K.
# 3   United-States    >50K.
# 4   United-States   <=50K.

# %% [markdown]
# # 2. Data Preprocessing

# %% [markdown]
# I notice a few problems immediately:
#
# - We don't have a column header for our data
# - There are unknown values in our test set (the question marks) that we need to deal with
# - The target values have periods at the end in the test set but do not in the training set ("<=50K." != "<=50K")

# %% [markdown]
# In the dataset description, we can see the column names.

# %%
col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 
              'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
             'wage_class']

# %%
train_set.columns = col_labels
test_set.columns = col_labels

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  wage_class      32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             16281 non-null  int64
#  1   workclass       16281 non-null  object
#  2   fnlwgt          16281 non-null  int64
#  3   education       16281 non-null  object
#  4   education_num   16281 non-null  int64
#  5   marital_status  16281 non-null  object
#  6   occupation      16281 non-null  object
#  7   relationship    16281 non-null  object
#  8   race            16281 non-null  object
#  9   sex             16281 non-null  object
#  10  capital_gain    16281 non-null  int64
#  11  capital_loss    16281 non-null  int64
#  12  hours_per_week  16281 non-null  int64
#  13  native_country  16281 non-null  object
#  14  wage_class      16281 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 1.9+ MB

# %% [markdown]
# Hmm. There don't seem to be any. According to the accompanying notes, the original datasets had 32561 in train and 16281 with test. However, unknowns are included and have been labeled with a question mark (?). The test results documented were done after removing all unknowns. Therefore, to see if we can beat their best results, we need to remove the same unknown rows.
#
# If we do so, we should have 30162 in train and 15060 in test. Let's see if we can remove all of these unknown rows.
#
# It turns out the question mark was actually entered with a space first. Let's do a simple test to see what would happen if we dropped all rows that contain an unknown marked with a ' ?'.

# %%
train_set.replace(' ?', np.nan).dropna().shape
# Out:
# (30162, 15)

# %%
test_set.replace(' ?', np.nan).dropna().shape
# Out:
# (15060, 15)

# %%
train_nomissing = train_set.replace(' ?', np.nan).dropna()
test_nomissing = test_set.replace(' ?', np.nan).dropna()

# %% [markdown]
# Now that we have taken care of the missing value problem, we still have an issue with the target income thresholds being encoded slightly differently in test vs. train. We need these to match up appropriately, so we are going to need to fix either the test or training set to make them match up. Let's replace all of the '<=50K.' with '<=50K' and the same for '>50K.' with '>50K'. This is also encoded with a space so include this in the string. We can use the replace method from pandas to fix this.

# %%
test_nomissing['wage_class'] = test_nomissing.wage_class.replace({' <=50K.': ' <=50K', ' >50K.':' >50K'})

# %% [markdown]
# #### Ordinal Encoder or One-Hot Encoder ?

# %% [markdown]
# Our next step is to encode the features with a string category since XGBoost (like all of the other machine learning algorithms in Python) requires every feature vector to include only digits. To do this properly, however, we will need to join the two together and apply our encoding so that the same categories exist in both datasets when we do train/test evaluation.
#
# There is some debate as to whether you are technically supposed to use one-hot encoding for categorical features (since there isn't supposed to be any inherent ordering) or you can use ordinal encoder. My master's Machine Learning teacher Qiwei Han found [this discussion](https://github.com/szilard/benchm-ml/issues/1) on the subject, that I found really interesting. It seems that one-hot encoding isn't necessary for tree-based algorithms, but you may run into a problem using this on linear models. Let's test them both and see it for ourselves!

# %%
data = pd.concat([train_nomissing, test_nomissing], axis = 0) # Stacks them vertically

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45222 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45222 non-null  int64
#  1   workclass       45222 non-null  object
#  2   fnlwgt          45222 non-null  int64
#  3   education       45222 non-null  object
#  4   education_num   45222 non-null  int64
#  5   marital_status  45222 non-null  object
#  6   occupation      45222 non-null  object
#  7   relationship    45222 non-null  object
#  8   race            45222 non-null  object
#  9   sex             45222 non-null  object
#  10  capital_gain    45222 non-null  int64
#  11  capital_loss    45222 non-null  int64
#  12  hours_per_week  45222 non-null  int64
#  13  native_country  45222 non-null  object
#  14  wage_class      45222 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.5+ MB

# %%
# We ransform 'wage_class' column into binary to be our target and drop the non binary column
data['wage_class_binary'] = data['wage_class'].apply(lambda x: 1 if x == ' >50K' else 0)
data = data.drop(columns='wage_class')

# %%
X = data.drop(columns='wage_class_binary')
y = data['wage_class_binary']

# %% [markdown]
# We will be using a pipeline code I developed has a template and just do the necessary minor changes

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# #### Ordinal Encoder

# %%
### PIPELINE ###

# Standard Scaler is not needed because:
# Tree-based models (like decision trees, random forests, and gradient boosting) are generally invariant to feature scaling.
# XGBoost's underlying decision trees can handle unscaled data effectively without performance loss.

# Simple Imputer is not needed because:
# XGBoost automatically learns the best way to handle missing values while building trees.

numerical_features = [
    'age',
    'fnlwgt',
    'education_num',
    'capital_gain',
    'capital_loss',
    'hours_per_week',
]

categorical_features = [
    'workclass',
    'education',
    'marital_status',
    'occupation', 
    'relationship',
    'race',
    'sex',
    'native_country'
]

preprocessor = ColumnTransformer(
    transformers=[
        # ('num', Pipeline(steps=[
            # ('imputer', SimpleImputer(strategy='mean')),
            # ('scaler', StandardScaler())
        # ]), numerical_features),
        ('cat', Pipeline(steps=[
            # ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OrdinalEncoder())
        ]), categorical_features)
    ])

X_categorical = X.copy()
X_categorical[categorical_features] = X_categorical[categorical_features].astype('category')

pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

X_ordinal = pipeline.fit_transform(X_categorical)

# %% [markdown]
# #### One-Hot Encoder

# %%
### PIPELINE ###

# Standard Scaler is not needed because:
# Tree-based models (like decision trees, random forests, and gradient boosting) are generally invariant to feature scaling.
# XGBoost's underlying decision trees can handle unscaled data effectively without performance loss.

# Simple Imputer is not needed because:
# XGBoost automatically learns the best way to handle missing values while building trees.

numerical_features = [
    'age',
    'fnlwgt',
    'education_num',
    'capital_gain',
    'capital_loss',
    'hours_per_week',
]

categorical_features = [
    'workclass',
    'education',
    'marital_status',
    'occupation', 
    'relationship',
    'race',
    'sex',
    'native_country'
]

preprocessor = ColumnTransformer(
    transformers=[
        # ('num', Pipeline(steps=[
            # ('imputer', SimpleImputer(strategy='mean')),
            # ('scaler', StandardScaler())
        # ]), numerical_features),
        ('cat', Pipeline(steps=[
            # ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]), categorical_features)
    ])

pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

X_one_hot = pipeline.fit_transform(X)

# %%
# Usually we would use train_test_split but in this case we can use the shape of the train & test sets 
# from before to keep the same rows in each set and be true to the exercise. Not that anybody cares.

# X = data.drop(columns='wage_class_binary')
# y = data['wage_class_binary']

# X_train, X_test, y_train, y_test = train_test_split(processed_data, y, test_size=0.2, random_state=42, stratify=y)

X_one_hot_train = X_one_hot[:train_nomissing.shape[0]] # Up to the last initial training set row
X_ordinal_train = X_ordinal[:train_nomissing.shape[0]] # Up to the last initial training set row
y_train = y[:train_nomissing.shape[0]] # Up to the last initial training set row

X_one_hot_test = X_one_hot[train_nomissing.shape[0]:] # Up to the last initial training set row
X_ordinal_test = X_ordinal[train_nomissing.shape[0]:] # Up to the last initial training set row
y_test = y[train_nomissing.shape[0]:]# Up to the last initial training set row

# %% [markdown]
# # 3. Model Training - Gridsearch Cross-Validation

# %% [markdown]
# First of all lets check y to see if we are dealing with class imbalance or not.

# %%
y_train.value_counts(dropna=False)
# Out:
# wage_class_binary
# 0    22654
# 1     7508
# Name: count, dtype: int64

# %% [markdown]
# We do have some class imbalance, we should take note and take it into account when defining our model

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import (precision_recall_curve, confusion_matrix, 
                             classification_report, roc_auc_score, 
                             average_precision_score)
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %% [markdown]
# When there is a class imbalance there are many methods one can use to approach the problem, I particularly like lowering the learning rate and increasing the max_depth, num_boost_rounds & early_stopping_rounds to let the model learn slower and for a longer time to pick more characteristics on the lower sampled class. This risk is overfitting of course so it's recommended to test some combinations and see how the model deals with the data in hand.

# %%
def custom_grid_search_cv_xgb(X_train, y_train, X_test, y_test):
    # This method of grid search enables us to use the cv function of xgb package to handle early stopping 
    # while at the same time tuning the hyperparameters of the model

    start_time = time.time()
    scale_pos_weight = np.sum(y_train == 0) / np.sum(y_train == 1)

    # Convert data to DMatrix: optimize both memory efficiency and computational speed
    dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)
    dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=True)

    # Define ranges for hyperparameter tuning
    param_grid = {
        'max_depth': [5, 7, 9],
        'min_child_weight': [1, 3, 5],
        'learning_rate': [0.01, 0.05, 0.1],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0]
    }

    # Setup StratifiedKFold
    skf = StratifiedKFold(n_splits = 3, shuffle= True, random_state=42)

    # Variables to track the best score and parameters
    best_params = None
    best_aucpr = 0

    # Loop through all combinations of hyperparameters
    for max_depth in param_grid['max_depth']:
        for min_child_weight in param_grid['min_child_weight']:
            for learning_rate in param_grid['learning_rate']:
                for subsample in param_grid['subsample']:
                    for colsample_bytree in param_grid['colsample_bytree']:
                        params = {
                            'objective': 'binary:logistic',
                            'eval_metric': 'aucpr',
                            'scale_pos_weight': scale_pos_weight,
                            'max_depth': max_depth,
                            'eta': learning_rate,
                            'subsample': subsample,
                            'colsample_bytree': colsample_bytree,
                            'min_child_weight': min_child_weight,
                            'random_state': 42
                        }
    
                        # Cross-validation 
                        cv_results = xgb.cv(
                            params,
                            dtrain,
                            num_boost_round=2000, # number of boosting rounds aka trees to build
                            folds=skf,
                            early_stopping_rounds=100, # Validation metric needs to improve at least once in every 
                                                        # early_stopping_rounds round(s) to continue training
                                                        # Overfitting prevention *
                            metrics='aucpr', # given the slight class imbalance and the nature of the problem 
                                            # I believe a good metric to judge the quality of our model
                            as_pandas=True,
                            seed=42,
                            verbose_eval=False
                        )
    
                        # Get the best score for the current combination of hyperparameters
                        mean_aucpr = cv_results['test-aucpr-mean'].max()
                        boost_rounds = cv_results['test-aucpr-mean'].idxmax()
    
                        if mean_aucpr > best_aucpr:
                            best_aucpr = mean_aucpr
                            best_params = params
                            best_boost_rounds = boost_rounds
                            print('NEW BEST!')
    
                        print(f"Test AUC-PR Mean: {mean_aucpr}, Boost Rounds: {boost_rounds}, Params: {params}")

    final_model = xgb.train(
        best_params,
        dtrain,
        num_boost_round=best_boost_rounds
    )

    y_pred_prob = final_model.predict(dtest)
    
    # Optimize threshold based on Precision-Recall curve
    precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_prob)
    optimal_idx = np.argmax(precisions + recalls)
    optimal_threshold = thresholds[optimal_idx]

    y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

    # Confusion Matrix
    cm_rf = confusion_matrix(y_test, y_pred_optimal)
    class_names = ['Class 0', 'Class 1']
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix - XGBoost')
    plt.show()

    # Classification report and ROC
    print('Classification Report:')
    print(classification_report(y_test, y_pred_optimal))

    roc_auc = roc_auc_score(y_test, y_pred_prob)
    print('ROC-AUC Score:')
    print(roc_auc)

    pr_auc = average_precision_score(y_test, y_pred_prob)
    print('PR AUC Score:')
    print(pr_auc)

    print('Best parameters:')
    print(best_params)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"
Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.6, 'colsample_bytree': 0.8, 'min_child_weight': 1, 'random_state': 42}
# Test AUC-PR Mean: 0.6939564985010773, Boost Rounds: 91, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 1, 'random_state': 42}
# ...
# Test AUC-PR Mean: 0.6901615598521201, Boost Rounds: 54, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 1, 'random_state': 42}
# Test AUC-PR Mean: 0.6965507703518358, Boost Rounds: 558, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.6, 'colsample_bytree': 0.6, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6959187984338947, Boost Rounds: 529, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.6, 'colsample_bytree': 0.8, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6953913692294988, Boost Rounds: 452, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6960824879424038, Boost Rounds: 605, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.6, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6953244980589629, Boost Rounds: 532, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6949955742819744, Boost Rounds: 501, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6946760251972334, Boost Rounds: 637, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 1.0, 'colsample_bytree': 0.6, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6936494845968214, Boost Rounds: 457, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 1.0, 'colsample_bytree': 0.8, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6932925796128666, Boost Rounds: 537, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6964864127837621, Boost Rounds: 153, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.6, 'colsample_bytree': 0.6, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6954555371181081, Boost Rounds: 110, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.6, 'colsample_bytree': 0.8, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6960486344389464, Boost Rounds: 89, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6957645551677878, Boost Rounds: 109, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.6, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.695358567435633, Boost Rounds: 129, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6948198753885908, Boost Rounds: 118, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6950450969225934, Boost Rounds: 146, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 1.0, 'colsample_bytree': 0.6, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6938965467343537, Boost Rounds: 143, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 1.0, 'colsample_bytree': 0.8, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.693718807339836, Boost Rounds: 94, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6964225333658439, Boost Rounds: 62, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6951558050042769, Boost Rounds: 49, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6946756966064727, Boost Rounds: 45, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6960127723216449, Boost Rounds: 63, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6953366117845615, Boost Rounds: 61, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6933919893635468, Boost Rounds: 65, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6952060648743149, Boost Rounds: 50, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6938713386640928, Boost Rounds: 58, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.6932346622915232, Boost Rounds: 41, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 3, 'random_state': 42}
# Test AUC-PR Mean: 0.697129716536395, Boost Rounds: 645, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.6, 'colsample_bytree': 0.6, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6963528998528595, Boost Rounds: 544, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.6, 'colsample_bytree': 0.8, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6956697753194653, Boost Rounds: 570, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6966572742456743, Boost Rounds: 643, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.6, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6956658733681144, Boost Rounds: 535, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6950121041107379, Boost Rounds: 522, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6953208142280367, Boost Rounds: 726, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 1.0, 'colsample_bytree': 0.6, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.694661550274879, Boost Rounds: 664, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 1.0, 'colsample_bytree': 0.8, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6940315142155479, Boost Rounds: 657, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.01, 'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.696613098265486, Boost Rounds: 154, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.6, 'colsample_bytree': 0.6, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6959087973864806, Boost Rounds: 128, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.6, 'colsample_bytree': 0.8, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6953610749116175, Boost Rounds: 81, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6963463381526499, Boost Rounds: 138, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.6, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6955797731926187, Boost Rounds: 125, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6948539202411617, Boost Rounds: 89, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.695215582948617, Boost Rounds: 119, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 1.0, 'colsample_bytree': 0.6, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6944077742779508, Boost Rounds: 137, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 1.0, 'colsample_bytree': 0.8, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6940822523665725, Boost Rounds: 137, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.05, 'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6966730306082539, Boost Rounds: 51, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6949805706546689, Boost Rounds: 58, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6944616803134308, Boost Rounds: 60, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6957623657718836, Boost Rounds: 61, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6950559951597559, Boost Rounds: 60, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6942938783011611, Boost Rounds: 52, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6951714341304994, Boost Rounds: 66, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6939843299416175, Boost Rounds: 56, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'min_child_weight': 5, 'random_state': 42}
# Test AUC-PR Mean: 0.6942125183817778, Boost Rounds: 59, Params: {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 9, 'eta': 0.1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'random_state': 42}
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.69      0.80     11360
#            1       0.48      0.90      0.63      3700
#
#     accuracy                           0.74     15060
#    macro avg       0.72      0.79      0.71     15060
# weighted avg       0.84      0.74      0.76     15060
#
# ROC-AUC Score:
# 0.8762076751046821
# PR AUC Score:
# 0.6862455827674465
# Best parameters:
# {'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': 3.017314864144912, 'max_depth': 5, 'eta': 0.1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'min_child_weight': 5, 'random_state': 42}
# Total time taken: 2658.44 seconds

# %% [markdown]
# After this test we arrived to the conclusion that both methods built good models, different but close in quality. Nevertheless, one-hot encoding ended up taking more time as predicted and does take more computer capacity, this difference will be increased if there are more categorical features in our dataset. Ordinal encoding didn't show any signal of inferiority and all the signs of higher perfomance so I recommend anyone that could be reading to take a look at it!
