# %% [markdown]
# # XGBoost

# %% [markdown]
# ### XGBoost Overview
#
# **XGBoost** (eXtreme Gradient Boosting) is a machine learning algorithm that is efficient and scalable for tasks like classification and regression. It is an implementation of gradient-boosted decision trees designed for high performance.
#
# #### Key Features
# - **Gradient Boosting**: Sequentially builds models to correct errors of previous ones.
# - **Regularization**: L1 and L2 regularization to prevent overfitting.
# - **Missing Values**: Handles missing data internally.
# - **Parallel Processing**: Optimized for speed using hardware resources.
# - **Tree Pruning**: Uses depth-first approach to prune trees.
#
# #### How XGBoost Works
# 1. **Initialization**: Start with an initial prediction (e.g., mean for regression).
# 2. **Residuals**: Compute the error (residuals).
# 3. **Fit Tree**: Fit a decision tree to the residuals.
# 4. **Update**: Update the prediction by adding the new tree.
# 5. **Repeat**: Continue until error is minimized.
#
# #### Important Parameters
# - **Learning Rate (eta)**: Controls contribution of each tree.
# - **Max Depth (max_depth)**: Maximum depth of each tree.
# - **Subsample**: Fraction of data used per tree.
# - **Colsample_bytree**: Fraction of features used per tree.
# - **n_estimators**: Number of boosting rounds.
#
# #### Objective Function
#
# The model minimizes the following objective function:
#
# $$
# \text{Obj} = \sum_{i=1}^{n} L(y_i, \hat{y}_i^{(t)}) + \sum_{t=1}^{T} \Omega(f_t)
# $$
#
# Where the first part is the loss function, and the second part is the regularization term.

# %% [markdown]
# ### Introduction
#
# In this notebook, we will level up our hyperparameter tuning! We will be using **Optuna**, a powerful and flexible optimization framework, to automate and streamline the process. Optuna allows us to efficiently search for the best hyperparameters using techniques like **Bayesian optimization** and **pruning**, which help identify the best values faster and with fewer resources.
#
# ### Key Steps We'll Cover:
#
# 1. **Setting Up the Objective Function**: We'll define a function that Optuna will optimize, which includes our model's training and evaluation steps.
# 2. **Configuring the Search Space**: We'll specify the hyperparameters and their ranges, allowing Optuna to explore various combinations.
# 3. **Running the Optimization**: Using Optuna's `study` feature, we'll run trials to identify the optimal hyperparameter values based on model performance.
# 4. **Analyzing Results**: After tuning, we’ll review and visualize the optimization results, including parameter importance and performance gains.
# 5. **Applying the Best Parameters**: Finally, we’ll retrain our model with the best parameters found by Optuna and evaluate its performance on test data.
#
# Lets start with our exercise! We will be training a XGBoost Classifier to try to predict whether a certain individual had an income of greater than 50,000 based on their demographic information.
#
# #### WARNING:
# This notebook follows the same exercise as the exercise in the notebook xgboost_gridsearch_cv just building the final model using Optuna hyperparameter tuning instead of doing a manual grid-search.

# %% [markdown]
# # 1. Load Data

# %%
# !pip install numpy== 1.26.4
# !pip install pandas== 2.2.1
# !pip install xgboost== 2.1.1
# !pip install seaborn== 0.13.2
# !pip install matplotlib == 3.8.3
# !pip install optuna == 4.0.0
# Out:
# ERROR: Invalid requirement: '=='
# ERROR: Invalid requirement: '=='
# ERROR: Invalid requirement: '=='
# ERROR: Invalid requirement: '=='
# ERROR: Invalid requirement: '=='
# ERROR: Invalid requirement: '=='

# %%
import numpy as np
import pandas as pd

# %%
train_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header = None)
test_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test', skiprows = 1, header = None) # Make sure to skip a row for the test set

# %%
train_set.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
test_set.head()
# Out:
#    0           1       2              3   4                    5   \
# 0  25     Private  226802           11th   7        Never-married
# 1  38     Private   89814        HS-grad   9   Married-civ-spouse
# 2  28   Local-gov  336951     Assoc-acdm  12   Married-civ-spouse
# 3  44     Private  160323   Some-college  10   Married-civ-spouse
# 4  18           ?  103497   Some-college  10        Never-married
#
#                    6           7       8        9     10  11  12  \
# 0   Machine-op-inspct   Own-child   Black     Male     0   0  40
# 1     Farming-fishing     Husband   White     Male     0   0  50
# 2     Protective-serv     Husband   White     Male     0   0  40
# 3   Machine-op-inspct     Husband   Black     Male  7688   0  40
# 4                   ?   Own-child   White   Female     0   0  30
#
#                13       14
# 0   United-States   <=50K.
# 1   United-States   <=50K.
# 2   United-States    >50K.
# 3   United-States    >50K.
# 4   United-States   <=50K.

# %% [markdown]
# # 2. Data Preprocessing

# %% [markdown]
# I notice a few problems immediately:
#
# - We don't have a column header for our data
# - There are unknown values in our test set (the question marks) that we need to deal with
# - The target values have periods at the end in the test set but do not in the training set ("<=50K." != "<=50K")

# %% [markdown]
# In the dataset description, we can see the column names.

# %%
col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 
              'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
             'wage_class']

# %%
train_set.columns = col_labels
test_set.columns = col_labels

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  wage_class      32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             16281 non-null  int64
#  1   workclass       16281 non-null  object
#  2   fnlwgt          16281 non-null  int64
#  3   education       16281 non-null  object
#  4   education_num   16281 non-null  int64
#  5   marital_status  16281 non-null  object
#  6   occupation      16281 non-null  object
#  7   relationship    16281 non-null  object
#  8   race            16281 non-null  object
#  9   sex             16281 non-null  object
#  10  capital_gain    16281 non-null  int64
#  11  capital_loss    16281 non-null  int64
#  12  hours_per_week  16281 non-null  int64
#  13  native_country  16281 non-null  object
#  14  wage_class      16281 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 1.9+ MB

# %% [markdown]
# Hmm. There don't seem to be any. According to the accompanying notes, the original datasets had 32561 in train and 16281 with test. However, unknowns are included and have been labeled with a question mark (?). The test results documented were done after removing all unknowns. Therefore, to see if we can beat their best results, we need to remove the same unknown rows.
#
# If we do so, we should have 30162 in train and 15060 in test. Let's see if we can remove all of these unknown rows.
#
# It turns out the question mark was actually entered with a space first. Let's do a simple test to see what would happen if we dropped all rows that contain an unknown marked with a ' ?'.

# %%
train_set.replace(' ?', np.nan).dropna().shape
# Out:
# (30162, 15)

# %%
test_set.replace(' ?', np.nan).dropna().shape
# Out:
# (15060, 15)

# %%
train_nomissing = train_set.replace(' ?', np.nan).dropna()
test_nomissing = test_set.replace(' ?', np.nan).dropna()

# %% [markdown]
# Now that we have taken care of the missing value problem, we still have an issue with the target income thresholds being encoded slightly differently in test vs. train. We need these to match up appropriately, so we are going to need to fix either the test or training set to make them match up. Let's replace all of the '<=50K.' with '<=50K' and the same for '>50K.' with '>50K'. This is also encoded with a space so include this in the string. We can use the replace method from pandas to fix this.

# %%
test_nomissing['wage_class'] = test_nomissing.wage_class.replace({' <=50K.': ' <=50K', ' >50K.':' >50K'})

# %% [markdown]
# #### Ordinal Encoder or One-Hot Encoder ?

# %% [markdown]
# Our next step is to encode the features with a string category since XGBoost (like all of the other machine learning algorithms in Python) requires every feature vector to include only digits. To do this properly, however, we will need to join the two together and apply our encoding so that the same categories exist in both datasets when we do train/test evaluation.
#
# There is some debate as to whether you are technically supposed to use one-hot encoding for categorical features (since there isn't supposed to be any inherent ordering) or you can use ordinal encoder. My master's Machine Learning teacher Qiwei Han found [this discussion](https://github.com/szilard/benchm-ml/issues/1) on the subject, that I found really interesting. It seems that one-hot encoding isn't necessary for tree-based algorithms, but you may run into a problem using this on linear models. Let's test them both and see it for ourselves!

# %%
data = pd.concat([train_nomissing, test_nomissing], axis = 0) # Stacks them vertically

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45222 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45222 non-null  int64
#  1   workclass       45222 non-null  object
#  2   fnlwgt          45222 non-null  int64
#  3   education       45222 non-null  object
#  4   education_num   45222 non-null  int64
#  5   marital_status  45222 non-null  object
#  6   occupation      45222 non-null  object
#  7   relationship    45222 non-null  object
#  8   race            45222 non-null  object
#  9   sex             45222 non-null  object
#  10  capital_gain    45222 non-null  int64
#  11  capital_loss    45222 non-null  int64
#  12  hours_per_week  45222 non-null  int64
#  13  native_country  45222 non-null  object
#  14  wage_class      45222 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.5+ MB

# %%
# We ransform 'wage_class' column into binary to be our target and drop the non binary column
data['wage_class_binary'] = data['wage_class'].apply(lambda x: 1 if x == ' >50K' else 0)
data = data.drop(columns='wage_class')

# %%
X = data.drop(columns='wage_class_binary')
y = data['wage_class_binary']

# %% [markdown]
# We will be using a pipeline code I developed has a template and just do the necessary minor changes

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# #### Ordinal Encoder

# %%
### PIPELINE ###

# Standard Scaler is not needed because:
# Tree-based models (like decision trees, random forests, and gradient boosting) are generally invariant to feature scaling.
# XGBoost's underlying decision trees can handle unscaled data effectively without performance loss.

# Simple Imputer is not needed because:
# XGBoost automatically learns the best way to handle missing values while building trees.

numerical_features = [
    'age',
    'fnlwgt',
    'education_num',
    'capital_gain',
    'capital_loss',
    'hours_per_week',
]

categorical_features = [
    'workclass',
    'education',
    'marital_status',
    'occupation', 
    'relationship',
    'race',
    'sex',
    'native_country'
]

preprocessor = ColumnTransformer(
    transformers=[
        # ('num', Pipeline(steps=[
            # ('imputer', SimpleImputer(strategy='mean')),
            # ('scaler', StandardScaler())
        # ]), numerical_features),
        ('cat', Pipeline(steps=[
            # ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OrdinalEncoder())
        ]), categorical_features)
    ])

X_categorical = X.copy()
X_categorical[categorical_features] = X_categorical[categorical_features].astype('category')

pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

X_ordinal = pipeline.fit_transform(X_categorical)

# %% [markdown]
# #### One-Hot Encoder

# %%
### PIPELINE ###

# Standard Scaler is not needed because:
# Tree-based models (like decision trees, random forests, and gradient boosting) are generally invariant to feature scaling.
# XGBoost's underlying decision trees can handle unscaled data effectively without performance loss.

# Simple Imputer is not needed because:
# XGBoost automatically learns the best way to handle missing values while building trees.

numerical_features = [
    'age',
    'fnlwgt',
    'education_num',
    'capital_gain',
    'capital_loss',
    'hours_per_week',
]

categorical_features = [
    'workclass',
    'education',
    'marital_status',
    'occupation', 
    'relationship',
    'race',
    'sex',
    'native_country'
]

preprocessor = ColumnTransformer(
    transformers=[
        # ('num', Pipeline(steps=[
            # ('imputer', SimpleImputer(strategy='mean')),
            # ('scaler', StandardScaler())
        # ]), numerical_features),
        ('cat', Pipeline(steps=[
            # ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]), categorical_features)
    ])

pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

X_one_hot = pipeline.fit_transform(X)

# %%
# Usually we would use train_test_split but in this case we can use the shape of the train & test sets 
# from before to keep the same rows in each set and be true to the exercise. Not that anybody cares.

# X = data.drop(columns='wage_class_binary')
# y = data['wage_class_binary']

# X_train, X_test, y_train, y_test = train_test_split(processed_data, y, test_size=0.2, random_state=42, stratify=y)

X_one_hot_train = X_one_hot[:train_nomissing.shape[0]] # Up to the last initial training set row
X_ordinal_train = X_ordinal[:train_nomissing.shape[0]] # Up to the last initial training set row
y_train = y[:train_nomissing.shape[0]] # Up to the last initial training set row

X_one_hot_test = X_one_hot[train_nomissing.shape[0]:] # Up to the last initial training set row
X_ordinal_test = X_ordinal[train_nomissing.shape[0]:] # Up to the last initial training set row
y_test = y[train_nomissing.shape[0]:]# Up to the last initial training set row

# %% [markdown]
# # 3. Model Training

# %% [markdown]
# First of all lets check y to see if we are dealing with class imbalance or not.

# %%
y_train.value_counts(dropna=False)
# Out:
# wage_class_binary
# 0    22654
# 1     7508
# Name: count, dtype: int64

# %% [markdown]
# We do have some class imbalance, we should take note and take it into account when defining our model

# %%
import optuna
import xgboost as xgb
from sklearn.metrics import precision_recall_curve, confusion_matrix, classification_report, roc_auc_score, average_precision_score
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
import time

# %% [markdown]
# When thre is class imbalance, we should lower the learning rate and increase the max_depth, num_boost_rounds & early_stopping_rounds to let the model learn slower and for longer time to pick more carachteristics on the lower sampled class. This risk overfitting of course so its recommended to test some combination and see how the model deals with the data in hand.

# %%
def objective(trial):
    # Define hyperparameter search space
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'aucpr',
        'scale_pos_weight':  trial.suggest_float('scale_pos_weight', scale_pos_weight*0.75, scale_pos_weight*2.5),  # Handle class imbalance
        'max_depth': trial.suggest_int('max_depth', 5, 9),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 5),
        'eta': trial.suggest_float('eta', 0.01, 0.1),  # learning rate
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'random_state': 42,
    }

    # Cross-validation with early stopping
    cv_results = xgb.cv(
        param,
        dtrain,
        folds=skf,
        metrics='aucpr',
        num_boost_round = 2000,
        early_stopping_rounds = 100,
        as_pandas=True,
        seed=42,
        verbose_eval=False
    )

    mean_aucpr = cv_results['test-aucpr-mean'].max()
    return mean_aucpr

def custom_optuna_xgb(X_train, y_train, X_test, y_test, n_trials=50, timeout=600):
    start_time = time.time()

    global scale_pos_weight
    scale_pos_weight = np.sum(y_train == 0) / np.sum(y_train == 1)  # Class imbalance

    # Convert data to DMatrix
    global dtrain, dtest, skf
    dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)
    dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=True)

    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

    # Create Optuna study to maximize AUC-PR
    study = optuna.create_study(direction='maximize', study_name='XGBoost')
    study.optimize(objective, n_trials=n_trials, timeout=timeout)  # Adjust n_trials and timeout

    # Best hyperparameters from Optuna
    best_params = study.best_params
    print(f"Best params: {best_params}")
    print(f"Best AUC-PR: {study.best_value}")

    # Add the validation dataset to evals
    evals = [(dtrain, 'train'), (dtest, 'eval')]

    # Train final model using best parameters
    final_model = xgb.train(
        {**best_params, 'objective': 'binary:logistic', 'eval_metric': 'aucpr', 'scale_pos_weight': scale_pos_weight},
        dtrain,
        num_boost_round=2000,
        early_stopping_rounds = 100,
        evals = evals,
    )

    # Prediction and evaluation
    y_pred_prob = final_model.predict(dtest)

    # Optimize threshold based on Precision-Recall curve
    precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_prob)
    optimal_idx = np.argmax(precisions + recalls)
    optimal_threshold = thresholds[optimal_idx]

    y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

    # Confusion Matrix
    cm_rf = confusion_matrix(y_test, y_pred_optimal)
    class_names = ['Class 0', 'Class 1']
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix - XGBoost')
    plt.show()

    # Classification report and ROC
    print('Classification Report:')
    print(classification_report(y_test, y_pred_optimal))

    roc_auc = roc_auc_score(y_test, y_pred_prob)
    print('ROC-AUC Score:')
    print(roc_auc)

    pr_auc = average_precision_score(y_test, y_pred_prob)
    print('PR AUC Score:')
    print(pr_auc)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Total time taken: {elapsed_time:.2f} seconds")

    return final_model

# %%
model_ordinal = custom_optuna_xgb(X_ordinal_train, y_train, X_ordinal_test, y_test, 500, 6000)
model_ordinal
# Out:
# [I 2024-10-26 14:56:03,567] A new study created in memory with name: XGBoost
# [I 2024-10-26 14:56:08,036] Trial 0 finished with value: 0.6956076636877379 and parameters: {'scale_pos_weight': 5.601263272481024, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.08985701897561786, 'subsample': 0.6366114096291845, 'colsample_bytree': 0.6384826088483171}. Best is trial 0 with value: 0.6956076636877379.
# [I 2024-10-26 14:56:14,250] Trial 1 finished with value: 0.6956268521738688 and parameters: {'scale_pos_weight': 7.472125300324585, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.06995437953087606, 'subsample': 0.8630402423575787, 'colsample_bytree': 0.8939827891222114}. Best is trial 1 with value: 0.6956268521738688.
# [I 2024-10-26 14:56:18,867] Trial 2 finished with value: 0.6947778866910527 and parameters: {'scale_pos_weight': 6.943175602311664, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.07014498822822433, 'subsample': 0.78229343271659, 'colsample_bytree': 0.8636763475448179}. Best is trial 1 with value: 0.6956268521738688.
# [I 2024-10-26 14:56:23,148] Trial 3 finished with value: 0.6948450033131993 and parameters: {'scale_pos_weight': 6.312115698980037, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.05854205529337072, 'subsample': 0.6850453776429184, 'colsample_bytree': 0.7321329687253438}. Best is trial 1 with value: 0.6956268521738688.
# [I 2024-10-26 14:56:26,976] Trial 4 finished with value: 0.693207438187511 and parameters: {'scale_pos_weight': 6.726267207312629, 'max_depth': 9, 'min_child_weight': 1, 'eta': 0.09847718845818916, 'subsample': 0.6800594303047901, 'colsample_bytree': 0.7281525784587504}. Best is trial 1 with value: 0.6956268521738688.
# [I 2024-10-26 14:56:34,656] Trial 5 finished with value: 0.6933962089775054 and parameters: {'scale_pos_weight': 5.716211239679803, 'max_depth': 7, 'min_child_weight': 2, 'eta': 0.019672731477601214, 'subsample': 0.8894418894884075, 'colsample_bytree': 0.8794198104999111}. Best is trial 1 with value: 0.6956268521738688.
# [I 2024-10-26 14:56:39,297] Trial 6 finished with value: 0.6965406127242902 and parameters: {'scale_pos_weight': 3.8437302207728097, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.07554668937567623, 'subsample': 0.9552771357099894, 'colsample_bytree': 0.6203562147206073}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:56:44,123] Trial 7 finished with value: 0.6945887635793538 and parameters: {'scale_pos_weight': 5.360151083576849, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.08936787614266142, 'subsample': 0.6008170341024526, 'colsample_bytree': 0.8785467304960779}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:56:47,999] Trial 8 finished with value: 0.6940311708674818 and parameters: {'scale_pos_weight': 5.311804636185737, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.08758263968609072, 'subsample': 0.6365192097610216, 'colsample_bytree': 0.9176123641461075}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:56:52,905] Trial 9 finished with value: 0.6925029959399612 and parameters: {'scale_pos_weight': 5.449755661254326, 'max_depth': 8, 'min_child_weight': 2, 'eta': 0.0453869057788282, 'subsample': 0.7337519298484964, 'colsample_bytree': 0.7736127604585186}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:56:58,614] Trial 10 finished with value: 0.6964041242761875 and parameters: {'scale_pos_weight': 3.32535409586254, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.0375900521926901, 'subsample': 0.9860110206094633, 'colsample_bytree': 0.6136627257293742}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:57:04,554] Trial 11 finished with value: 0.6965096844900677 and parameters: {'scale_pos_weight': 3.3899586977518785, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.03626455900924116, 'subsample': 0.9784252553432486, 'colsample_bytree': 0.6068761853834868}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:57:17,179] Trial 12 finished with value: 0.6954401735508827 and parameters: {'scale_pos_weight': 3.8484107396641045, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.021209578249516498, 'subsample': 0.9974897486949449, 'colsample_bytree': 0.6709461471671228}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:57:23,364] Trial 13 finished with value: 0.6964253363084164 and parameters: {'scale_pos_weight': 2.450840342151471, 'max_depth': 8, 'min_child_weight': 4, 'eta': 0.034810492621466335, 'subsample': 0.9230494734773842, 'colsample_bytree': 0.6027026300819033}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:57:28,144] Trial 14 finished with value: 0.6953207061314287 and parameters: {'scale_pos_weight': 4.31715573369503, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.0630551104817974, 'subsample': 0.9422187800265085, 'colsample_bytree': 0.6890595635307462}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:57:33,110] Trial 15 finished with value: 0.6910272725138514 and parameters: {'scale_pos_weight': 2.6777951082851033, 'max_depth': 8, 'min_child_weight': 1, 'eta': 0.04869529934125338, 'subsample': 0.8380262462255121, 'colsample_bytree': 0.9926902594985161}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:57:37,666] Trial 16 finished with value: 0.6949645767064355 and parameters: {'scale_pos_weight': 4.349438624627059, 'max_depth': 6, 'min_child_weight': 3, 'eta': 0.0762356634802216, 'subsample': 0.9379878298521973, 'colsample_bytree': 0.6687310799905611}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:57:51,598] Trial 17 finished with value: 0.6958574092666385 and parameters: {'scale_pos_weight': 3.289837301751396, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.012538653375295188, 'subsample': 0.8002186687604037, 'colsample_bytree': 0.8197234592894668}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:58:00,224] Trial 18 finished with value: 0.6946978944427458 and parameters: {'scale_pos_weight': 4.558534216955808, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.029214745962821285, 'subsample': 0.9633274940948241, 'colsample_bytree': 0.7136204925252709}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:58:05,177] Trial 19 finished with value: 0.694166172963406 and parameters: {'scale_pos_weight': 3.5102353043215064, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.05134733869486713, 'subsample': 0.9056155087802383, 'colsample_bytree': 0.7755927297311732}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:58:08,869] Trial 20 finished with value: 0.6949690022762511 and parameters: {'scale_pos_weight': 3.0060695189666147, 'max_depth': 8, 'min_child_weight': 3, 'eta': 0.0785730692877785, 'subsample': 0.8535754169100874, 'colsample_bytree': 0.6427797815830081}. Best is trial 6 with value: 0.6965406127242902.
# [I 2024-10-26 14:58:14,876] Trial 21 finished with value: 0.6965789663016633 and parameters: {'scale_pos_weight': 2.5579119460046895, 'max_depth': 8, 'min_child_weight': 4, 'eta': 0.03701993958131574, 'subsample': 0.9215849092755597, 'colsample_bytree': 0.6185980818417072}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:58:20,521] Trial 22 finished with value: 0.6965649445554772 and parameters: {'scale_pos_weight': 3.7601091473911556, 'max_depth': 8, 'min_child_weight': 4, 'eta': 0.038573599480701055, 'subsample': 0.9647217294613801, 'colsample_bytree': 0.6021899956760164}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:58:24,407] Trial 23 finished with value: 0.6953668026177363 and parameters: {'scale_pos_weight': 2.3345560955221933, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.042507818441209703, 'subsample': 0.8903243855525025, 'colsample_bytree': 0.6448422207712905}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:58:30,209] Trial 24 finished with value: 0.6940686172665359 and parameters: {'scale_pos_weight': 3.8308514161782705, 'max_depth': 8, 'min_child_weight': 4, 'eta': 0.027262240452687565, 'subsample': 0.944985643251531, 'colsample_bytree': 0.6947036704208125}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:58:35,117] Trial 25 finished with value: 0.6945557059997526 and parameters: {'scale_pos_weight': 2.910308019214344, 'max_depth': 8, 'min_child_weight': 3, 'eta': 0.05849043604067035, 'subsample': 0.8273349972379512, 'colsample_bytree': 0.6359504731607959}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:58:39,089] Trial 26 finished with value: 0.6946796710562815 and parameters: {'scale_pos_weight': 4.832425273396606, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.04269479507405509, 'subsample': 0.9106227741559578, 'colsample_bytree': 0.6638171596628739}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:58:44,038] Trial 27 finished with value: 0.6960646379726659 and parameters: {'scale_pos_weight': 4.019214851153582, 'max_depth': 8, 'min_child_weight': 3, 'eta': 0.052934264846996176, 'subsample': 0.9633666752367459, 'colsample_bytree': 0.6023136578117939}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:58:49,902] Trial 28 finished with value: 0.6927447049709743 and parameters: {'scale_pos_weight': 2.895474594458497, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.029234408366112928, 'subsample': 0.8747880003830164, 'colsample_bytree': 0.758156047147805}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:58:56,117] Trial 29 finished with value: 0.6959845695021736 and parameters: {'scale_pos_weight': 4.871194687414642, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.06652337776952286, 'subsample': 0.9560864087869951, 'colsample_bytree': 0.6302377100582913}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:58:59,855] Trial 30 finished with value: 0.6912617514350692 and parameters: {'scale_pos_weight': 3.6114879758160594, 'max_depth': 8, 'min_child_weight': 1, 'eta': 0.08389401675250581, 'subsample': 0.994992033242818, 'colsample_bytree': 0.8206159361849819}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:59:05,762] Trial 31 finished with value: 0.696336772725524 and parameters: {'scale_pos_weight': 3.2134177020175865, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.036006875656965025, 'subsample': 0.9708209234504979, 'colsample_bytree': 0.6188430644548363}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:59:13,883] Trial 32 finished with value: 0.6962701657960754 and parameters: {'scale_pos_weight': 4.092316553010785, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.038783096503618185, 'subsample': 0.9134689925265305, 'colsample_bytree': 0.6578117248633566}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:59:19,822] Trial 33 finished with value: 0.696324665306148 and parameters: {'scale_pos_weight': 2.690211587854159, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.031655756083936504, 'subsample': 0.9801826619894882, 'colsample_bytree': 0.600202548595308}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:59:32,958] Trial 34 finished with value: 0.6963674805105545 and parameters: {'scale_pos_weight': 3.7438839369702777, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.02498202679554056, 'subsample': 0.9304469186692795, 'colsample_bytree': 0.6964722947111655}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:59:36,677] Trial 35 finished with value: 0.6951109133447456 and parameters: {'scale_pos_weight': 3.4373358586599077, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.09962003456216639, 'subsample': 0.7644937074045, 'colsample_bytree': 0.629518534839984}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:59:41,656] Trial 36 finished with value: 0.6938476073677163 and parameters: {'scale_pos_weight': 2.5965918667404524, 'max_depth': 8, 'min_child_weight': 4, 'eta': 0.05672304241540571, 'subsample': 0.8896557198968535, 'colsample_bytree': 0.6518052151787302}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 14:59:56,464] Trial 37 finished with value: 0.6951793219739671 and parameters: {'scale_pos_weight': 3.170257376560632, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.012631707676144216, 'subsample': 0.9733126229595371, 'colsample_bytree': 0.7333152425637668}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 15:00:00,063] Trial 38 finished with value: 0.6949260146719175 and parameters: {'scale_pos_weight': 6.041403056326802, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.04822525437211466, 'subsample': 0.8680336538204745, 'colsample_bytree': 0.6821201592993846}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 15:00:05,328] Trial 39 finished with value: 0.6964370725497643 and parameters: {'scale_pos_weight': 7.346829698981134, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.07466363668060289, 'subsample': 0.9537782677960545, 'colsample_bytree': 0.6220515788019487}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 15:00:12,504] Trial 40 finished with value: 0.6954857453533165 and parameters: {'scale_pos_weight': 4.639303293227948, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.06258075144558164, 'subsample': 0.9989109475000861, 'colsample_bytree': 0.7158596792426385}. Best is trial 21 with value: 0.6965789663016633.
# [I 2024-10-26 15:00:18,357] Trial 41 finished with value: 0.6968206244372636 and parameters: {'scale_pos_weight': 6.606306154107984, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.07202606164891186, 'subsample': 0.9513585506013116, 'colsample_bytree': 0.622929766331126}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:00:22,999] Trial 42 finished with value: 0.696275071990641 and parameters: {'scale_pos_weight': 6.438136247827094, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.0832199699636989, 'subsample': 0.9278341462961156, 'colsample_bytree': 0.6204743683666556}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:00:27,654] Trial 43 finished with value: 0.6946159713705088 and parameters: {'scale_pos_weight': 5.140573689136149, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.0938920762214824, 'subsample': 0.9791863864935115, 'colsample_bytree': 0.6455471191602495}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:00:32,726] Trial 44 finished with value: 0.6929227096112379 and parameters: {'scale_pos_weight': 4.215215400811183, 'max_depth': 7, 'min_child_weight': 1, 'eta': 0.06808498494368473, 'subsample': 0.9512951462654602, 'colsample_bytree': 0.9136755550605942}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:00:41,966] Trial 45 finished with value: 0.6959930299862979 and parameters: {'scale_pos_weight': 5.835264068992236, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.04028800141667323, 'subsample': 0.7229979087398857, 'colsample_bytree': 0.611005226324376}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:00:55,839] Trial 46 finished with value: 0.6953610740986355 and parameters: {'scale_pos_weight': 7.0206147706552535, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.019559299677862494, 'subsample': 0.9049896447797651, 'colsample_bytree': 0.6757265651882307}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:01,796] Trial 47 finished with value: 0.69348381587335 and parameters: {'scale_pos_weight': 2.279448186796556, 'max_depth': 8, 'min_child_weight': 1, 'eta': 0.03359571679796739, 'subsample': 0.9299160142953401, 'colsample_bytree': 0.6582528226641056}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:07,277] Trial 48 finished with value: 0.6964711454307119 and parameters: {'scale_pos_weight': 3.6331967258850724, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07226625838809962, 'subsample': 0.981278778064588, 'colsample_bytree': 0.6000496207089693}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:13,103] Trial 49 finished with value: 0.6946173132078082 and parameters: {'scale_pos_weight': 3.964132196103732, 'max_depth': 7, 'min_child_weight': 2, 'eta': 0.04691060097933488, 'subsample': 0.9461610912181492, 'colsample_bytree': 0.6328687321058417}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:18,603] Trial 50 finished with value: 0.6949708148874416 and parameters: {'scale_pos_weight': 5.164953645045207, 'max_depth': 6, 'min_child_weight': 3, 'eta': 0.06156076353961862, 'subsample': 0.8079092372631328, 'colsample_bytree': 0.8478037500967861}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:24,408] Trial 51 finished with value: 0.6964436570051178 and parameters: {'scale_pos_weight': 4.448366498535948, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07211513006167233, 'subsample': 0.9821656495995622, 'colsample_bytree': 0.6022553049248927}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:30,196] Trial 52 finished with value: 0.6966026123176112 and parameters: {'scale_pos_weight': 3.6141736396579263, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07193454558237768, 'subsample': 0.9654827243089176, 'colsample_bytree': 0.6199898887629974}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:35,214] Trial 53 finished with value: 0.6965525659062184 and parameters: {'scale_pos_weight': 3.012445803073691, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07985659081482332, 'subsample': 0.9602385073135344, 'colsample_bytree': 0.6177020276747691}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:40,276] Trial 54 finished with value: 0.6964287837203381 and parameters: {'scale_pos_weight': 2.771480283749545, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.08000174492602641, 'subsample': 0.9629265349769119, 'colsample_bytree': 0.6219267462669222}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:44,891] Trial 55 finished with value: 0.6949392995539476 and parameters: {'scale_pos_weight': 3.0648150377006487, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.08534343893960293, 'subsample': 0.9406288044966991, 'colsample_bytree': 0.638426748009455}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:49,124] Trial 56 finished with value: 0.6957138849733225 and parameters: {'scale_pos_weight': 3.4580896602348994, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.0948151490086217, 'subsample': 0.9184750500251198, 'colsample_bytree': 0.6534018224308823}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:53,198] Trial 57 finished with value: 0.6945473457627531 and parameters: {'scale_pos_weight': 2.482074566698061, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.08008532774701682, 'subsample': 0.8914483614674928, 'colsample_bytree': 0.9912262300689342}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:01:58,360] Trial 58 finished with value: 0.6951308369789806 and parameters: {'scale_pos_weight': 2.8727201434191487, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.06654146000602981, 'subsample': 0.9982788680348705, 'colsample_bytree': 0.6716386456386846}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:03,658] Trial 59 finished with value: 0.696534388473764 and parameters: {'scale_pos_weight': 3.142066671351531, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.07561468645164249, 'subsample': 0.9621427037029412, 'colsample_bytree': 0.6160446691149225}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:08,212] Trial 60 finished with value: 0.6949234702153557 and parameters: {'scale_pos_weight': 3.8293893598273723, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.08690939660569558, 'subsample': 0.6375903935524874, 'colsample_bytree': 0.700478293117233}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:11,788] Trial 61 finished with value: 0.6963413875380917 and parameters: {'scale_pos_weight': 3.2406249782008967, 'max_depth': 8, 'min_child_weight': 4, 'eta': 0.07522645376686396, 'subsample': 0.9593541396261623, 'colsample_bytree': 0.6162396757633654}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:16,807] Trial 62 finished with value: 0.694314148411929 and parameters: {'scale_pos_weight': 3.6108558025669963, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.0696709503844656, 'subsample': 0.9379237605131179, 'colsample_bytree': 0.6402169169963816}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:20,302] Trial 63 finished with value: 0.6939794161584042 and parameters: {'scale_pos_weight': 3.06226747900419, 'max_depth': 8, 'min_child_weight': 4, 'eta': 0.07749012747372785, 'subsample': 0.9671892912647467, 'colsample_bytree': 0.6294662709222162}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:25,411] Trial 64 finished with value: 0.6964248199897002 and parameters: {'scale_pos_weight': 2.5804687976447793, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.08964597587490765, 'subsample': 0.9193011906054177, 'colsample_bytree': 0.6119397240844241}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:29,522] Trial 65 finished with value: 0.6948425638996037 and parameters: {'scale_pos_weight': 4.175968893861528, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.08250987082820556, 'subsample': 0.9020025217921813, 'colsample_bytree': 0.6621040247488869}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:35,192] Trial 66 finished with value: 0.696111662845245 and parameters: {'scale_pos_weight': 3.348207997586673, 'max_depth': 6, 'min_child_weight': 3, 'eta': 0.06419014226580301, 'subsample': 0.9489127063413118, 'colsample_bytree': 0.614012956901618}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:39,296] Trial 67 finished with value: 0.694552241388808 and parameters: {'scale_pos_weight': 2.7921118783121535, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.07265011087097599, 'subsample': 0.991460356202683, 'colsample_bytree': 0.6431357337777017}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:42,907] Trial 68 finished with value: 0.6953484100249016 and parameters: {'scale_pos_weight': 3.112867916055328, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.05120549749736383, 'subsample': 0.9339078728739929, 'colsample_bytree': 0.6281790981284009}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:46,580] Trial 69 finished with value: 0.6950291250366657 and parameters: {'scale_pos_weight': 2.427109775826299, 'max_depth': 8, 'min_child_weight': 5, 'eta': 0.05988266864219158, 'subsample': 0.8500579798995881, 'colsample_bytree': 0.6832738730449147}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:50,204] Trial 70 finished with value: 0.6944442040105124 and parameters: {'scale_pos_weight': 3.964596362722979, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.0929279940549182, 'subsample': 0.970588223758027, 'colsample_bytree': 0.6528916627717307}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:02:56,017] Trial 71 finished with value: 0.6965370747720087 and parameters: {'scale_pos_weight': 3.36254931486923, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.036716646820144805, 'subsample': 0.97262607253543, 'colsample_bytree': 0.6098322050312629}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:03:02,316] Trial 72 finished with value: 0.6965607517668929 and parameters: {'scale_pos_weight': 3.667695007914642, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.04340199661995707, 'subsample': 0.9581594384218943, 'colsample_bytree': 0.6109480212753835}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:03:08,993] Trial 73 finished with value: 0.6953549600003859 and parameters: {'scale_pos_weight': 3.659560852115297, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.04346834287495828, 'subsample': 0.9843361912304505, 'colsample_bytree': 0.6307546625028836}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:03:15,185] Trial 74 finished with value: 0.6922350876315977 and parameters: {'scale_pos_weight': 2.9644764398450105, 'max_depth': 8, 'min_child_weight': 5, 'eta': 0.033202616338882815, 'subsample': 0.9520651638645157, 'colsample_bytree': 0.9644092574698135}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:03:21,375] Trial 75 finished with value: 0.6964145274834929 and parameters: {'scale_pos_weight': 3.493038720042615, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.0390865130538618, 'subsample': 0.9727143895372664, 'colsample_bytree': 0.6017651899091914}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:03:29,422] Trial 76 finished with value: 0.6954560666037836 and parameters: {'scale_pos_weight': 3.7982210860638164, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.036100523364634686, 'subsample': 0.9383794839402806, 'colsample_bytree': 0.6460778075097491}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:03:34,848] Trial 77 finished with value: 0.6962382129430909 and parameters: {'scale_pos_weight': 3.2939334389477772, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.04218028944929338, 'subsample': 0.987953842896225, 'colsample_bytree': 0.6120347028531066}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:03:45,562] Trial 78 finished with value: 0.6963149212651927 and parameters: {'scale_pos_weight': 4.623458069399909, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.02923221530982483, 'subsample': 0.9226738326529069, 'colsample_bytree': 0.6228136015906066}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:03:50,780] Trial 79 finished with value: 0.6938795935896694 and parameters: {'scale_pos_weight': 6.658462492899767, 'max_depth': 8, 'min_child_weight': 2, 'eta': 0.045986114190968375, 'subsample': 0.7664983183266072, 'colsample_bytree': 0.6659249286080857}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:03:58,490] Trial 80 finished with value: 0.6957267808145483 and parameters: {'scale_pos_weight': 4.251792097647827, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.03169253341486532, 'subsample': 0.8765106377497248, 'colsample_bytree': 0.7937881136784084}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:05,015] Trial 81 finished with value: 0.6960768373245131 and parameters: {'scale_pos_weight': 3.378438438064252, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.025514482704107812, 'subsample': 0.9615778284163273, 'colsample_bytree': 0.6158342692351252}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:09,131] Trial 82 finished with value: 0.6934904052123633 and parameters: {'scale_pos_weight': 3.569862878247228, 'max_depth': 7, 'min_child_weight': 1, 'eta': 0.08075059155394743, 'subsample': 0.9566079111355074, 'colsample_bytree': 0.6348952842717315}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:13,369] Trial 83 finished with value: 0.6963614059359303 and parameters: {'scale_pos_weight': 4.0527661012930905, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.07759075656622619, 'subsample': 0.9728214009035685, 'colsample_bytree': 0.6109338744516802}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:17,133] Trial 84 finished with value: 0.6960421628941832 and parameters: {'scale_pos_weight': 3.1700602375055955, 'max_depth': 8, 'min_child_weight': 4, 'eta': 0.07409651773550012, 'subsample': 0.9471874952741827, 'colsample_bytree': 0.6234616101125274}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:21,646] Trial 85 finished with value: 0.6963713556073187 and parameters: {'scale_pos_weight': 3.742406464128703, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.06917159703660665, 'subsample': 0.9894238841709895, 'colsample_bytree': 0.6085601545741054}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:26,247] Trial 86 finished with value: 0.6947963003661105 and parameters: {'scale_pos_weight': 2.7273444988336326, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.06544212782491998, 'subsample': 0.9302569995965704, 'colsample_bytree': 0.6492147164471255}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:35,407] Trial 87 finished with value: 0.6956739552076332 and parameters: {'scale_pos_weight': 3.898538731229237, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.03764910283518615, 'subsample': 0.9650953415004284, 'colsample_bytree': 0.746807630544675}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:40,655] Trial 88 finished with value: 0.6924486579634149 and parameters: {'scale_pos_weight': 7.363306672137545, 'max_depth': 8, 'min_child_weight': 1, 'eta': 0.05461413304615327, 'subsample': 0.9114056184118973, 'colsample_bytree': 0.6403729021800038}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:45,859] Trial 89 finished with value: 0.695832387458765 and parameters: {'scale_pos_weight': 4.425020852092881, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.04075983881042554, 'subsample': 0.9780014131888319, 'colsample_bytree': 0.6010276773991018}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:53,289] Trial 90 finished with value: 0.6950983216834689 and parameters: {'scale_pos_weight': 5.554949987707651, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.05078895317476604, 'subsample': 0.940873729972207, 'colsample_bytree': 0.6322169625612126}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:04:58,764] Trial 91 finished with value: 0.6963758494852762 and parameters: {'scale_pos_weight': 2.9368149681958147, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.03558497445101264, 'subsample': 0.9571690936241265, 'colsample_bytree': 0.6226536372883249}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:05:05,006] Trial 92 finished with value: 0.696420152308827 and parameters: {'scale_pos_weight': 3.4635381339855194, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.04379707041683424, 'subsample': 0.9738855873493846, 'colsample_bytree': 0.6085175178879895}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:05:11,804] Trial 93 finished with value: 0.69611613892735 and parameters: {'scale_pos_weight': 3.7060094300946123, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.03169238627942347, 'subsample': 0.9938617009413215, 'colsample_bytree': 0.6190905539381643}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:05:18,293] Trial 94 finished with value: 0.6953037335044988 and parameters: {'scale_pos_weight': 3.258581238592988, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.03779704610021826, 'subsample': 0.947509032492354, 'colsample_bytree': 0.6384797613002455}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:05:23,489] Trial 95 finished with value: 0.6963038401404046 and parameters: {'scale_pos_weight': 2.5848302473230946, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07130116711402876, 'subsample': 0.9642286447754562, 'colsample_bytree': 0.6083788074768781}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:05:28,563] Trial 96 finished with value: 0.6948720569768851 and parameters: {'scale_pos_weight': 5.992115868092323, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.07645794294355578, 'subsample': 0.9815643156286841, 'colsample_bytree': 0.6583682840300162}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:05:33,029] Trial 97 finished with value: 0.6945549169737687 and parameters: {'scale_pos_weight': 2.856548882170899, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.08173752484805187, 'subsample': 0.9246075983994606, 'colsample_bytree': 0.6264063218835966}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:05:37,951] Trial 98 finished with value: 0.6959194930028354 and parameters: {'scale_pos_weight': 3.3809901928240267, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.08457255616754852, 'subsample': 0.9998489156282859, 'colsample_bytree': 0.6008175751595567}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:05:44,149] Trial 99 finished with value: 0.693255585260006 and parameters: {'scale_pos_weight': 3.5330335544058356, 'max_depth': 8, 'min_child_weight': 1, 'eta': 0.03349068399255533, 'subsample': 0.9584144347671444, 'colsample_bytree': 0.6479509031492559}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:05:55,481] Trial 100 finished with value: 0.6964276537033897 and parameters: {'scale_pos_weight': 3.032782190549472, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.021376642301731377, 'subsample': 0.8989326722352526, 'colsample_bytree': 0.6168592424804447}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:00,873] Trial 101 finished with value: 0.6966348089798778 and parameters: {'scale_pos_weight': 3.6248733790886716, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07327656634768022, 'subsample': 0.9846538179495038, 'colsample_bytree': 0.6000261921651173}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:05,947] Trial 102 finished with value: 0.6963583670553866 and parameters: {'scale_pos_weight': 3.1650672188505387, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07877934774734935, 'subsample': 0.986855302351417, 'colsample_bytree': 0.6081331648597949}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:11,324] Trial 103 finished with value: 0.695377063850022 and parameters: {'scale_pos_weight': 3.710213896800291, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07415822075725696, 'subsample': 0.967147159423797, 'colsample_bytree': 0.6276708153747173}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:18,002] Trial 104 finished with value: 0.6962456603492212 and parameters: {'scale_pos_weight': 3.912931800369587, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.04034659514025782, 'subsample': 0.9519964607639412, 'colsample_bytree': 0.6158683878685071}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:23,326] Trial 105 finished with value: 0.6951056221700048 and parameters: {'scale_pos_weight': 4.125047007086551, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06863042629099349, 'subsample': 0.9779940122846005, 'colsample_bytree': 0.6334823611305053}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:28,643] Trial 106 finished with value: 0.6968164231721089 and parameters: {'scale_pos_weight': 3.552356007033156, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.0710573184515084, 'subsample': 0.7087624858072685, 'colsample_bytree': 0.6076981057284869}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:33,271] Trial 107 finished with value: 0.6960239995723437 and parameters: {'scale_pos_weight': 3.5804676811856013, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.07525020425771436, 'subsample': 0.6795104899374916, 'colsample_bytree': 0.6230832887001384}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:37,967] Trial 108 finished with value: 0.6958975247359227 and parameters: {'scale_pos_weight': 3.303340156433687, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.07051749048554941, 'subsample': 0.6859244787764237, 'colsample_bytree': 0.6066565389366697}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:42,689] Trial 109 finished with value: 0.6951487383579856 and parameters: {'scale_pos_weight': 3.840721945614249, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.07298565477642084, 'subsample': 0.7895428911410508, 'colsample_bytree': 0.8542821862629445}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:47,774] Trial 110 finished with value: 0.6960063075451526 and parameters: {'scale_pos_weight': 3.427167976296686, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.07725181883453579, 'subsample': 0.7282129594999879, 'colsample_bytree': 0.6000669624431034}. Best is trial 41 with value: 0.6968206244372636.
# [I 2024-10-26 15:06:53,489] Trial 111 finished with value: 0.6974127337725834 and parameters: {'scale_pos_weight': 7.038137610341664, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06708026702581514, 'subsample': 0.6328348066260026, 'colsample_bytree': 0.6148205787707842}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:06:58,527] Trial 112 finished with value: 0.6951210487749705 and parameters: {'scale_pos_weight': 7.136249570461036, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06634921591135699, 'subsample': 0.6288734660905697, 'colsample_bytree': 0.6370346841033956}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:07:03,846] Trial 113 finished with value: 0.6962045888585146 and parameters: {'scale_pos_weight': 6.902603171618875, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.06729593759674077, 'subsample': 0.6051356357989502, 'colsample_bytree': 0.6142289752026222}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:07:08,944] Trial 114 finished with value: 0.6961758105123163 and parameters: {'scale_pos_weight': 6.488682611626047, 'max_depth': 6, 'min_child_weight': 3, 'eta': 0.07890007401804497, 'subsample': 0.706791487730213, 'colsample_bytree': 0.6203017963574227}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:07:14,696] Trial 115 finished with value: 0.6955851501642568 and parameters: {'scale_pos_weight': 7.522693130426548, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06417491520591904, 'subsample': 0.7542208018478602, 'colsample_bytree': 0.6293794527005308}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:07:19,587] Trial 116 finished with value: 0.6964175209995224 and parameters: {'scale_pos_weight': 6.908841710527736, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.07123319210743209, 'subsample': 0.6791187744773887, 'colsample_bytree': 0.6432979548668756}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:07:24,569] Trial 117 finished with value: 0.6966551076964049 and parameters: {'scale_pos_weight': 5.024184962622856, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07358361621184413, 'subsample': 0.6900732137612966, 'colsample_bytree': 0.6069495073638905}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:07:30,734] Trial 118 finished with value: 0.6967938475921515 and parameters: {'scale_pos_weight': 5.008234304985707, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07283060413130293, 'subsample': 0.6595259381547006, 'colsample_bytree': 0.6066100068739143}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:07:36,532] Trial 119 finished with value: 0.6972849010596834 and parameters: {'scale_pos_weight': 5.119727395276003, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06068157391938275, 'subsample': 0.6423557560254136, 'colsample_bytree': 0.6067399539504638}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:07:42,694] Trial 120 finished with value: 0.6970447969433132 and parameters: {'scale_pos_weight': 5.0137060050657425, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.0581572943736328, 'subsample': 0.6497475178567533, 'colsample_bytree': 0.6000342534826062}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:07:48,949] Trial 121 finished with value: 0.6966882114650517 and parameters: {'scale_pos_weight': 4.958554752404985, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.059937322812726956, 'subsample': 0.6560198282371269, 'colsample_bytree': 0.6054600242260735}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:07:55,186] Trial 122 finished with value: 0.6967606787762562 and parameters: {'scale_pos_weight': 5.00173377294444, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05688614252297454, 'subsample': 0.65578251677868, 'colsample_bytree': 0.6064512692483526}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:08:01,291] Trial 123 finished with value: 0.6968164697017217 and parameters: {'scale_pos_weight': 4.986763544396294, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06179742758473954, 'subsample': 0.6574349950267578, 'colsample_bytree': 0.600103799448535}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:08:07,419] Trial 124 finished with value: 0.6972902707034465 and parameters: {'scale_pos_weight': 4.973098945264866, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05845503052220133, 'subsample': 0.6573152921285421, 'colsample_bytree': 0.6010527734899567}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:08:13,518] Trial 125 finished with value: 0.6971306647067417 and parameters: {'scale_pos_weight': 4.993268231038826, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.058661786453165325, 'subsample': 0.6574455100268196, 'colsample_bytree': 0.6071686632334383}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:08:19,806] Trial 126 finished with value: 0.6967553937552404 and parameters: {'scale_pos_weight': 5.003266815877789, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05763104423663853, 'subsample': 0.6555631736180318, 'colsample_bytree': 0.6000823596529319}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:08:25,513] Trial 127 finished with value: 0.6967359808159355 and parameters: {'scale_pos_weight': 5.020594204738033, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.057697295633606024, 'subsample': 0.6559235135406299, 'colsample_bytree': 0.604933706735991}. Best is trial 111 with value: 0.6974127337725834.
# [I 2024-10-26 15:08:31,425] Trial 128 finished with value: 0.697453035241041 and parameters: {'scale_pos_weight': 4.7527069379771785, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05860989396059377, 'subsample': 0.6596828346272798, 'colsample_bytree': 0.6067247820683795}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:08:37,335] Trial 129 finished with value: 0.6968726609384998 and parameters: {'scale_pos_weight': 4.787726895991266, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05531162862145456, 'subsample': 0.6587777325807358, 'colsample_bytree': 0.6135962869935262}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:08:43,072] Trial 130 finished with value: 0.6965738516266008 and parameters: {'scale_pos_weight': 4.775370174353848, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05615214484850955, 'subsample': 0.6533603280958754, 'colsample_bytree': 0.6269273021700428}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:08:48,953] Trial 131 finished with value: 0.6971478629138246 and parameters: {'scale_pos_weight': 5.249879178533795, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05807663873533568, 'subsample': 0.6629747007821417, 'colsample_bytree': 0.6124516381861815}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:08:55,223] Trial 132 finished with value: 0.6967935383299012 and parameters: {'scale_pos_weight': 5.32315140342416, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.060873397235596774, 'subsample': 0.645289909252922, 'colsample_bytree': 0.614264646245992}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:01,463] Trial 133 finished with value: 0.6969155213201418 and parameters: {'scale_pos_weight': 5.355177536799541, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.060571477611099905, 'subsample': 0.6662850735608591, 'colsample_bytree': 0.6133677597907684}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:07,658] Trial 134 finished with value: 0.6969575380493686 and parameters: {'scale_pos_weight': 5.279203530670882, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06128965873205617, 'subsample': 0.6682489125450792, 'colsample_bytree': 0.6170280259214377}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:14,047] Trial 135 finished with value: 0.6965984079958177 and parameters: {'scale_pos_weight': 5.21174192298387, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05348634255353207, 'subsample': 0.668801946627848, 'colsample_bytree': 0.6210073586294494}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:18,821] Trial 136 finished with value: 0.6945067710251324 and parameters: {'scale_pos_weight': 5.453883036620696, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06276689925157672, 'subsample': 0.622740627869857, 'colsample_bytree': 0.8912261033433584}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:24,091] Trial 137 finished with value: 0.6964894201006292 and parameters: {'scale_pos_weight': 4.752754671430764, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.059390866501728014, 'subsample': 0.665406501349059, 'colsample_bytree': 0.63005788222398}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:30,234] Trial 138 finished with value: 0.6967484187067585 and parameters: {'scale_pos_weight': 5.68022938563467, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05460921324062236, 'subsample': 0.6688995279051687, 'colsample_bytree': 0.6142642830943905}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:35,081] Trial 139 finished with value: 0.6955621546286057 and parameters: {'scale_pos_weight': 5.230634393638393, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06141639598602007, 'subsample': 0.6411585799576822, 'colsample_bytree': 0.6353113817863939}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:40,496] Trial 140 finished with value: 0.6967647821971613 and parameters: {'scale_pos_weight': 5.468186547044159, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06484523685535214, 'subsample': 0.6280768854546601, 'colsample_bytree': 0.6261432887420854}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:46,482] Trial 141 finished with value: 0.6963944759703051 and parameters: {'scale_pos_weight': 5.29179098676178, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06119302437685537, 'subsample': 0.645890299471663, 'colsample_bytree': 0.6138418683695783}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:51,494] Trial 142 finished with value: 0.6962123327165557 and parameters: {'scale_pos_weight': 5.08368918450581, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.0597750859402261, 'subsample': 0.6974999006714162, 'colsample_bytree': 0.61320657588919}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:09:57,589] Trial 143 finished with value: 0.6962031976955151 and parameters: {'scale_pos_weight': 5.35694586917969, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06343003019475492, 'subsample': 0.6457697542811929, 'colsample_bytree': 0.6206043540053048}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:10:03,747] Trial 144 finished with value: 0.6970849553000171 and parameters: {'scale_pos_weight': 4.836311347289207, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.055892336445023796, 'subsample': 0.618269550872828, 'colsample_bytree': 0.6111602998065085}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:10:10,355] Trial 145 finished with value: 0.6967715892943579 and parameters: {'scale_pos_weight': 4.860019404646725, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.04961743101556356, 'subsample': 0.6167905043602762, 'colsample_bytree': 0.6001851263523895}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:10:16,590] Trial 146 finished with value: 0.6969506120794366 and parameters: {'scale_pos_weight': 4.733781772892715, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05244384107742563, 'subsample': 0.6344310410817179, 'colsample_bytree': 0.6095978851611789}. Best is trial 128 with value: 0.697453035241041.
# [I 2024-10-26 15:10:23,788] Trial 147 finished with value: 0.6968717724321923 and parameters: {'scale_pos_weight': 4.683060202294368, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.05255770498119917, 'subsample': 0.611151828542754, 'colsample_bytree': 0.6236316564493004}. Best is trial 128 with value: 0.697453035241041.
# ...
# [I 2024-10-26 15:45:06,100] Trial 486 finished with value: 0.697062059083414 and parameters: {'scale_pos_weight': 3.577513689678294, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.055024174426715575, 'subsample': 0.6442853843825067, 'colsample_bytree': 0.6003713556556952}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:45:11,681] Trial 487 finished with value: 0.6965785003698161 and parameters: {'scale_pos_weight': 4.55520688931135, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06021758153645464, 'subsample': 0.6799895198168309, 'colsample_bytree': 0.6220518553162755}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:45:17,810] Trial 488 finished with value: 0.6972735997672311 and parameters: {'scale_pos_weight': 4.207306788497892, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05063866082784342, 'subsample': 0.6654260149291568, 'colsample_bytree': 0.6124264795480429}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:45:23,389] Trial 489 finished with value: 0.6959942066680278 and parameters: {'scale_pos_weight': 6.326109822042346, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.056799832969701945, 'subsample': 0.654056156783674, 'colsample_bytree': 0.6359933478229378}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:45:29,035] Trial 490 finished with value: 0.6968647791152542 and parameters: {'scale_pos_weight': 4.42726786810241, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.053930324799775275, 'subsample': 0.6388034648443064, 'colsample_bytree': 0.6249513435831866}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:45:35,348] Trial 491 finished with value: 0.6967275598865413 and parameters: {'scale_pos_weight': 7.017009296154891, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05832680466732562, 'subsample': 0.6105008151116922, 'colsample_bytree': 0.6064916575518485}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:45:41,265] Trial 492 finished with value: 0.6969177441070552 and parameters: {'scale_pos_weight': 3.6768847926616464, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.052338205423900164, 'subsample': 0.6720880476797013, 'colsample_bytree': 0.614633572436622}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:45:47,486] Trial 493 finished with value: 0.6971527206262684 and parameters: {'scale_pos_weight': 4.026702455318195, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.055866321491416335, 'subsample': 0.6311760821261346, 'colsample_bytree': 0.6067684435041295}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:45:53,768] Trial 494 finished with value: 0.6968084131783362 and parameters: {'scale_pos_weight': 4.319056182626373, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.06931689693523234, 'subsample': 0.7484360225019143, 'colsample_bytree': 0.6191654734895419}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:46:00,086] Trial 495 finished with value: 0.6964538006142703 and parameters: {'scale_pos_weight': 5.551151803586237, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.0540983649275867, 'subsample': 0.6609167831006141, 'colsample_bytree': 0.6545760822226424}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:46:06,524] Trial 496 finished with value: 0.6967828442028418 and parameters: {'scale_pos_weight': 4.8399931242730645, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.04982546118544711, 'subsample': 0.6003096171459021, 'colsample_bytree': 0.6131607163291342}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:46:12,659] Trial 497 finished with value: 0.6965380664038454 and parameters: {'scale_pos_weight': 4.622857121043015, 'max_depth': 6, 'min_child_weight': 3, 'eta': 0.06056428473696577, 'subsample': 0.6468328281822028, 'colsample_bytree': 0.6007428601024994}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:46:18,866] Trial 498 finished with value: 0.6953202565734556 and parameters: {'scale_pos_weight': 3.8318876320055044, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.05749375737033656, 'subsample': 0.6225670069278539, 'colsample_bytree': 0.6290199986573547}. Best is trial 401 with value: 0.6978540229561561.
# [I 2024-10-26 15:46:24,281] Trial 499 finished with value: 0.6966285536689464 and parameters: {'scale_pos_weight': 4.769837954979641, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0
# [197]	train-aucpr:0.71517	eval-aucpr:0.68878
# [198]	train-aucpr:0.71519	eval-aucpr:0.68888
# [199]	train-aucpr:0.71518	eval-aucpr:0.68882
# [200]	train-aucpr:0.71526	eval-aucpr:0.68879
# [201]	train-aucpr:0.71527	eval-aucpr:0.68870
# [202]	train-aucpr:0.71530	eval-aucpr:0.68861
# [203]	train-aucpr:0.71532	eval-aucpr:0.68860
# [204]	train-aucpr:0.71535	eval-aucpr:0.68856
# [205]	train-aucpr:0.71539	eval-aucpr:0.68859
# [206]	train-aucpr:0.71544	eval-aucpr:0.68837
# [207]	train-aucpr:0.71545	eval-aucpr:0.68847
# [208]	train-aucpr:0.71547	eval-aucpr:0.68841
# [209]	train-aucpr:0.71554	eval-aucpr:0.68849
# [210]	train-aucpr:0.71562	eval-aucpr:0.68857
# [211]	train-aucpr:0.71575	eval-aucpr:0.68856
# [212]	train-aucpr:0.71579	eval-aucpr:0.68848
# [213]	train-aucpr:0.71600	eval-aucpr:0.68847
# [214]	train-aucpr:0.71590	eval-aucpr:0.68839
# [215]	train-aucpr:0.71593	eval-aucpr:0.68829
# [216]	train-aucpr:0.71600	eval-aucpr:0.68848
# [217]	train-aucpr:0.71606	eval-aucpr:0.68837
# [218]	train-aucpr:0.71612	eval-aucpr:0.68834
# [219]	train-aucpr:0.71618	eval-aucpr:0.68839
# [220]	train-aucpr:0.71620	eval-aucpr:0.68825
# [221]	train-aucpr:0.71629	eval-aucpr:0.68811
# [222]	train-aucpr:0.71619	eval-aucpr:0.68828
# [223]	train-aucpr:0.71619	eval-aucpr:0.68827
# [224]	train-aucpr:0.71625	eval-aucpr:0.68833
# [225]	train-aucpr:0.71624	eval-aucpr:0.68837
# [226]	train-aucpr:0.71625	eval-aucpr:0.68835
# [227]	train-aucpr:0.71618	eval-aucpr:0.68840
# [228]	train-aucpr:0.71617	eval-aucpr:0.68865
# [229]	train-aucpr:0.71622	eval-aucpr:0.68878
# [230]	train-aucpr:0.71631	eval-aucpr:0.68874
# [231]	train-aucpr:0.71633	eval-aucpr:0.68883
# [232]	train-aucpr:0.71637	eval-aucpr:0.68888
# [233]	train-aucpr:0.71645	eval-aucpr:0.68888
# [234]	train-aucpr:0.71647	eval-aucpr:0.68884
# [235]	train-aucpr:0.71642	eval-aucpr:0.68845
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.68      0.80     11360
#            1       0.48      0.90      0.63      3700
#
#     accuracy                           0.74     15060
#    macro avg       0.72      0.79      0.71     15060
# weighted avg       0.84      0.74      0.75     15060
#
# ROC-AUC Score:
# 0.8755671988009137
# PR AUC Score:
# 0.6872369134273029
# Total time taken: 3025.25 seconds

# %%
model_one_hot = custom_optuna_xgb(X_one_hot_train, y_train, X_one_hot_test, y_test, 500, 6000)
model_one_hot
# Out:
# [I 2024-10-26 15:46:28,918] A new study created in memory with name: XGBoost
# [I 2024-10-26 15:46:42,227] Trial 0 finished with value: 0.6965038531681089 and parameters: {'scale_pos_weight': 4.570202688790964, 'max_depth': 7, 'min_child_weight': 1, 'eta': 0.02222984109616287, 'subsample': 0.8064884734487502, 'colsample_bytree': 0.9406806547823858}. Best is trial 0 with value: 0.6965038531681089.
# [I 2024-10-26 15:46:49,818] Trial 1 finished with value: 0.6966096107490182 and parameters: {'scale_pos_weight': 2.5746377755008396, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.04911471797172819, 'subsample': 0.9956405317730377, 'colsample_bytree': 0.8277284813896889}. Best is trial 1 with value: 0.6966096107490182.
# [I 2024-10-26 15:46:55,235] Trial 2 finished with value: 0.6970183530817486 and parameters: {'scale_pos_weight': 5.369894472853461, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.07191827205673723, 'subsample': 0.8106158422770765, 'colsample_bytree': 0.6224959544360661}. Best is trial 2 with value: 0.6970183530817486.
# [I 2024-10-26 15:47:11,283] Trial 3 finished with value: 0.6977206750658027 and parameters: {'scale_pos_weight': 3.16137791632652, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.018395449496308218, 'subsample': 0.8092786354098115, 'colsample_bytree': 0.8770224831191731}. Best is trial 3 with value: 0.6977206750658027.
# [I 2024-10-26 15:47:24,481] Trial 4 finished with value: 0.694606629253483 and parameters: {'scale_pos_weight': 6.325004290729996, 'max_depth': 9, 'min_child_weight': 5, 'eta': 0.0146976166289087, 'subsample': 0.8496316023004273, 'colsample_bytree': 0.9705120408171566}. Best is trial 3 with value: 0.6977206750658027.
# [I 2024-10-26 15:47:35,123] Trial 5 finished with value: 0.6974993881932642 and parameters: {'scale_pos_weight': 6.162019037658833, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.027535476426468836, 'subsample': 0.7565106357690529, 'colsample_bytree': 0.7481061844625534}. Best is trial 3 with value: 0.6977206750658027.
# [I 2024-10-26 15:47:40,124] Trial 6 finished with value: 0.6966102223206354 and parameters: {'scale_pos_weight': 3.4458131404482213, 'max_depth': 8, 'min_child_weight': 5, 'eta': 0.06742107898463605, 'subsample': 0.7476699913216915, 'colsample_bytree': 0.8256774607676832}. Best is trial 3 with value: 0.6977206750658027.
# [I 2024-10-26 15:47:45,142] Trial 7 finished with value: 0.6970834626367043 and parameters: {'scale_pos_weight': 3.317238125104182, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.09688267212270503, 'subsample': 0.6557347203852698, 'colsample_bytree': 0.745622597801642}. Best is trial 3 with value: 0.6977206750658027.
# [I 2024-10-26 15:48:08,135] Trial 8 finished with value: 0.6981838108220435 and parameters: {'scale_pos_weight': 3.9714055016014873, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.014700581437745776, 'subsample': 0.9306151648265644, 'colsample_bytree': 0.8070259156189539}. Best is trial 8 with value: 0.6981838108220435.
# [I 2024-10-26 15:48:19,725] Trial 9 finished with value: 0.6969149780471696 and parameters: {'scale_pos_weight': 6.806533791442745, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.03864554801917308, 'subsample': 0.950653476918132, 'colsample_bytree': 0.9961060144336282}. Best is trial 8 with value: 0.6981838108220435.
# [I 2024-10-26 15:48:24,904] Trial 10 finished with value: 0.6974703595472467 and parameters: {'scale_pos_weight': 4.517374771793513, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.09774195462854698, 'subsample': 0.9058685373960511, 'colsample_bytree': 0.6344205648324506}. Best is trial 8 with value: 0.6981838108220435.
# [I 2024-10-26 15:48:48,344] Trial 11 finished with value: 0.6969423534022235 and parameters: {'scale_pos_weight': 3.6212529420774113, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.010896365032074477, 'subsample': 0.8945057113981911, 'colsample_bytree': 0.8846704225951344}. Best is trial 8 with value: 0.6981838108220435.
# [I 2024-10-26 15:48:57,746] Trial 12 finished with value: 0.6972998661915684 and parameters: {'scale_pos_weight': 2.324941334567632, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.035281316383990104, 'subsample': 0.6613218690020886, 'colsample_bytree': 0.8995459905030505}. Best is trial 8 with value: 0.6981838108220435.
# [I 2024-10-26 15:49:04,971] Trial 13 finished with value: 0.6979205459457131 and parameters: {'scale_pos_weight': 3.9860400178969058, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.04641698483846711, 'subsample': 0.7209138942508018, 'colsample_bytree': 0.755088709806719}. Best is trial 8 with value: 0.6981838108220435.
# [I 2024-10-26 15:49:11,555] Trial 14 finished with value: 0.6989318292238464 and parameters: {'scale_pos_weight': 4.157636976431686, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.05727705555769884, 'subsample': 0.7198725705116555, 'colsample_bytree': 0.7135914829491188}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:49:19,956] Trial 15 finished with value: 0.697749032860341 and parameters: {'scale_pos_weight': 5.151786716723017, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.06322181456168667, 'subsample': 0.6245765311885503, 'colsample_bytree': 0.6839954602252492}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:49:24,432] Trial 16 finished with value: 0.695658625080324 and parameters: {'scale_pos_weight': 4.154318077156212, 'max_depth': 8, 'min_child_weight': 3, 'eta': 0.08130081988598813, 'subsample': 0.7011285306743833, 'colsample_bytree': 0.6905090854441617}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:49:33,919] Trial 17 finished with value: 0.6976152416429363 and parameters: {'scale_pos_weight': 5.274119799776998, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.05667409023196927, 'subsample': 0.8708194787525692, 'colsample_bytree': 0.7843820870225147}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:49:39,590] Trial 18 finished with value: 0.6952624466297479 and parameters: {'scale_pos_weight': 5.886824651011135, 'max_depth': 8, 'min_child_weight': 4, 'eta': 0.0812508742941823, 'subsample': 0.9925264283272252, 'colsample_bytree': 0.69781911904507}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:49:50,128] Trial 19 finished with value: 0.6979438967133315 and parameters: {'scale_pos_weight': 2.8915522210344893, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.033010020046526714, 'subsample': 0.951067058284384, 'colsample_bytree': 0.8098538504459036}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:49:56,836] Trial 20 finished with value: 0.6958215522795003 and parameters: {'scale_pos_weight': 7.363796047584275, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.04557031378389926, 'subsample': 0.7721866539659851, 'colsample_bytree': 0.6590481104131974}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:50:08,082] Trial 21 finished with value: 0.697891995883102 and parameters: {'scale_pos_weight': 2.8500960086486806, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.03008956242123977, 'subsample': 0.9437132954690761, 'colsample_bytree': 0.8028329739898427}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:50:22,909] Trial 22 finished with value: 0.6978788573529427 and parameters: {'scale_pos_weight': 3.8965963364471143, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02451983351544173, 'subsample': 0.9476810094403056, 'colsample_bytree': 0.7327413240983304}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:50:30,724] Trial 23 finished with value: 0.697930976616969 and parameters: {'scale_pos_weight': 2.942381781650618, 'max_depth': 6, 'min_child_weight': 3, 'eta': 0.039096753486636195, 'subsample': 0.8428829087256645, 'colsample_bytree': 0.8530659316421472}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:50:37,264] Trial 24 finished with value: 0.6980761178870539 and parameters: {'scale_pos_weight': 4.421855969615157, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.05881322227513937, 'subsample': 0.9322531659414858, 'colsample_bytree': 0.7828413474597593}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:50:44,110] Trial 25 finished with value: 0.6970813991910436 and parameters: {'scale_pos_weight': 4.739405959111304, 'max_depth': 6, 'min_child_weight': 3, 'eta': 0.05920327858971096, 'subsample': 0.9087024840996987, 'colsample_bytree': 0.7794136537384417}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:50:50,028] Trial 26 finished with value: 0.6986939411567302 and parameters: {'scale_pos_weight': 4.280288108959145, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.07671605177513013, 'subsample': 0.7052042684374061, 'colsample_bytree': 0.7208382937227443}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:50:55,604] Trial 27 finished with value: 0.6976505863083942 and parameters: {'scale_pos_weight': 3.737286643005075, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.07630837968471343, 'subsample': 0.6973006891534327, 'colsample_bytree': 0.719522298142541}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:51:01,306] Trial 28 finished with value: 0.6982567661390745 and parameters: {'scale_pos_weight': 4.916404228044242, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.08777746155701474, 'subsample': 0.722029799930999, 'colsample_bytree': 0.6509095721222429}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:51:06,039] Trial 29 finished with value: 0.6970617456000783 and parameters: {'scale_pos_weight': 5.642482082558901, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.09114358549808182, 'subsample': 0.6097580733700841, 'colsample_bytree': 0.6428725723322668}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:51:11,375] Trial 30 finished with value: 0.6967132271344494 and parameters: {'scale_pos_weight': 5.035541834952215, 'max_depth': 7, 'min_child_weight': 2, 'eta': 0.09062635333196872, 'subsample': 0.7301590991656167, 'colsample_bytree': 0.6016001374976564}. Best is trial 14 with value: 0.6989318292238464.
# [I 2024-10-26 15:51:17,290] Trial 31 finished with value: 0.6989543956442374 and parameters: {'scale_pos_weight': 4.276520354724524, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.08343365372718213, 'subsample': 0.7857749952601668, 'colsample_bytree': 0.66808941840572}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:51:22,981] Trial 32 finished with value: 0.6978657419910009 and parameters: {'scale_pos_weight': 4.806284384727102, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.08559321839205024, 'subsample': 0.7835859808603249, 'colsample_bytree': 0.6661814170428815}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:51:29,910] Trial 33 finished with value: 0.697400420678742 and parameters: {'scale_pos_weight': 4.416553210813288, 'max_depth': 5, 'min_child_weight': 1, 'eta': 0.07262985318459854, 'subsample': 0.6749866073185684, 'colsample_bytree': 0.7145461083557637}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:51:35,527] Trial 34 finished with value: 0.6979606145965828 and parameters: {'scale_pos_weight': 4.254865863981397, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.07901432174975298, 'subsample': 0.712366987702847, 'colsample_bytree': 0.6003380608254311}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:51:41,142] Trial 35 finished with value: 0.696909673872038 and parameters: {'scale_pos_weight': 4.8344646589428155, 'max_depth': 6, 'min_child_weight': 1, 'eta': 0.08698136211802093, 'subsample': 0.7876576801165543, 'colsample_bytree': 0.6702997764925768}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:51:46,409] Trial 36 finished with value: 0.6967191573199717 and parameters: {'scale_pos_weight': 5.459039660787884, 'max_depth': 7, 'min_child_weight': 2, 'eta': 0.06988160648784124, 'subsample': 0.7469397866361007, 'colsample_bytree': 0.707283347020931}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:51:53,395] Trial 37 finished with value: 0.6980063576567042 and parameters: {'scale_pos_weight': 4.60244028707294, 'max_depth': 5, 'min_child_weight': 1, 'eta': 0.06562934176017407, 'subsample': 0.8327030139324416, 'colsample_bytree': 0.6466488577126885}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:51:59,640] Trial 38 finished with value: 0.6974639348129149 and parameters: {'scale_pos_weight': 3.5104505697750175, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.051789236186174335, 'subsample': 0.6818787670766261, 'colsample_bytree': 0.680980551802615}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:52:05,081] Trial 39 finished with value: 0.6972203013691772 and parameters: {'scale_pos_weight': 4.201632055950868, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.07545176281778206, 'subsample': 0.6414559447657434, 'colsample_bytree': 0.625520690486382}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:52:11,366] Trial 40 finished with value: 0.6977594976381097 and parameters: {'scale_pos_weight': 4.981712049271225, 'max_depth': 5, 'min_child_weight': 1, 'eta': 0.09249223996624462, 'subsample': 0.8174146841389041, 'colsample_bytree': 0.7539297089869348}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:52:17,416] Trial 41 finished with value: 0.6983864412114821 and parameters: {'scale_pos_weight': 3.8599314300273653, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.08546836332904673, 'subsample': 0.7601900371938743, 'colsample_bytree': 0.847659260825021}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:52:23,429] Trial 42 finished with value: 0.6976376481044069 and parameters: {'scale_pos_weight': 3.152945734706125, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.08481398069300292, 'subsample': 0.7664059650801713, 'colsample_bytree': 0.9268429935487785}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:52:28,826] Trial 43 finished with value: 0.6973963949867157 and parameters: {'scale_pos_weight': 3.7183283413373585, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.09570825707142075, 'subsample': 0.7430281406747685, 'colsample_bytree': 0.8428392622179904}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:52:34,994] Trial 44 finished with value: 0.6971573053040668 and parameters: {'scale_pos_weight': 4.003589474543703, 'max_depth': 5, 'min_child_weight': 2, 'eta': 0.08880898092502858, 'subsample': 0.805297830150609, 'colsample_bytree': 0.7318023584592583}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:52:40,507] Trial 45 finished with value: 0.6976223275687415 and parameters: {'scale_pos_weight': 3.3799456790787024, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.08310727612150336, 'subsample': 0.728223137124316, 'colsample_bytree': 0.8599227136203255}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:52:46,735] Trial 46 finished with value: 0.6977605498376077 and parameters: {'scale_pos_weight': 4.525784557902048, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.07352887615269671, 'subsample': 0.7598042129440973, 'colsample_bytree': 0.763926376143647}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:52:51,843] Trial 47 finished with value: 0.6971246633872714 and parameters: {'scale_pos_weight': 4.24081793636115, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.09932560177112659, 'subsample': 0.6807722714094189, 'colsample_bytree': 0.6537473580555715}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:52:57,762] Trial 48 finished with value: 0.6968465375681264 and parameters: {'scale_pos_weight': 3.7647540852814085, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.0782402103206039, 'subsample': 0.7067122935728835, 'colsample_bytree': 0.9153836879625158}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:53:02,938] Trial 49 finished with value: 0.6978327841568738 and parameters: {'scale_pos_weight': 3.198438125428438, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.09458179175472188, 'subsample': 0.7383775573766551, 'colsample_bytree': 0.8292798454895792}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:53:10,174] Trial 50 finished with value: 0.6968215489832703 and parameters: {'scale_pos_weight': 5.578276783932278, 'max_depth': 6, 'min_child_weight': 2, 'eta': 0.06984376392684556, 'subsample': 0.8260572478859822, 'colsample_bytree': 0.9556232032380161}. Best is trial 31 with value: 0.6989543956442374.
# [I 2024-10-26 15:53:24,568] Trial 51 finished with value: 0.6990745698896713 and parameters: {'scale_pos_weight': 4.010731411426423, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.019691715573225466, 'subsample': 0.7921095492167892, 'colsample_bytree': 0.6181874940102821}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:53:32,584] Trial 52 finished with value: 0.6982388639240474 and parameters: {'scale_pos_weight': 4.024842810814491, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.045216672039783655, 'subsample': 0.7943490973425462, 'colsample_bytree': 0.624938702047747}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:53:38,397] Trial 53 finished with value: 0.6983197762802437 and parameters: {'scale_pos_weight': 4.635845266871081, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.0810354933608781, 'subsample': 0.7668775919520814, 'colsample_bytree': 0.695723681959594}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:53:44,768] Trial 54 finished with value: 0.6985527850067977 and parameters: {'scale_pos_weight': 4.3540211672015605, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.06319897333526542, 'subsample': 0.775293353013999, 'colsample_bytree': 0.693823838482389}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:53:49,801] Trial 55 finished with value: 0.6953469520912599 and parameters: {'scale_pos_weight': 4.306973710253539, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.0621521440160386, 'subsample': 0.7804219862768369, 'colsample_bytree': 0.6774553196594156}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:54:05,072] Trial 56 finished with value: 0.6989455126094287 and parameters: {'scale_pos_weight': 3.883620126910538, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.01996488590657646, 'subsample': 0.8602541307355104, 'colsample_bytree': 0.6120186585878353}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:54:21,823] Trial 57 finished with value: 0.6990295731226633 and parameters: {'scale_pos_weight': 3.5144818524287684, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.01669243259611926, 'subsample': 0.8565627246129239, 'colsample_bytree': 0.6214118718857121}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:54:38,498] Trial 58 finished with value: 0.6981231887520435 and parameters: {'scale_pos_weight': 3.5235403121740485, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.017184435984502, 'subsample': 0.8631918889963737, 'colsample_bytree': 0.6162029437702601}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:54:48,684] Trial 59 finished with value: 0.696880857353049 and parameters: {'scale_pos_weight': 4.057448936614199, 'max_depth': 8, 'min_child_weight': 4, 'eta': 0.022110518781604752, 'subsample': 0.8814223545092115, 'colsample_bytree': 0.6150102138105605}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:55:15,199] Trial 60 finished with value: 0.6984039770552517 and parameters: {'scale_pos_weight': 3.049156857590609, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.010059329478462078, 'subsample': 0.8454902345894709, 'colsample_bytree': 0.6327414423112377}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:55:30,184] Trial 61 finished with value: 0.6988914883001357 and parameters: {'scale_pos_weight': 3.615011065336006, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.022140193086598328, 'subsample': 0.8594978467500012, 'colsample_bytree': 0.6403446468323725}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:55:43,908] Trial 62 finished with value: 0.6986942647541032 and parameters: {'scale_pos_weight': 2.6330209861559446, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02175529529401631, 'subsample': 0.856544680624262, 'colsample_bytree': 0.6411570165982694}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:55:57,582] Trial 63 finished with value: 0.6987243930960695 and parameters: {'scale_pos_weight': 2.5749266520846614, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.022199922648310413, 'subsample': 0.8588095395086087, 'colsample_bytree': 0.6366137852523446}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:56:10,849] Trial 64 finished with value: 0.6979997253761088 and parameters: {'scale_pos_weight': 2.406377195864071, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02764127142973325, 'subsample': 0.8861542096986412, 'colsample_bytree': 0.6086400835250961}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:56:31,009] Trial 65 finished with value: 0.698330262153457 and parameters: {'scale_pos_weight': 2.7797526633152625, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.01484256730233452, 'subsample': 0.9052841968039125, 'colsample_bytree': 0.6595172589791385}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:56:48,028] Trial 66 finished with value: 0.6986135248096326 and parameters: {'scale_pos_weight': 3.2665096242322926, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.018180791403287055, 'subsample': 0.8743917128196517, 'colsample_bytree': 0.6346719159465524}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:57:00,061] Trial 67 finished with value: 0.6982351448209024 and parameters: {'scale_pos_weight': 3.6056932049178076, 'max_depth': 6, 'min_child_weight': 4, 'eta': 0.02555321740422365, 'subsample': 0.8161521501209971, 'colsample_bytree': 0.6158770657587164}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:57:10,709] Trial 68 finished with value: 0.6984578499209051 and parameters: {'scale_pos_weight': 3.3568591051947276, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.03424626177167721, 'subsample': 0.839047385815014, 'colsample_bytree': 0.6686116465643687}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:57:32,828] Trial 69 finished with value: 0.6985052603327722 and parameters: {'scale_pos_weight': 3.8457013580835335, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.012765269287524562, 'subsample': 0.854442196722214, 'colsample_bytree': 0.6305567496338494}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:57:45,433] Trial 70 finished with value: 0.6984117345644839 and parameters: {'scale_pos_weight': 2.5657363366167534, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.030522692979607184, 'subsample': 0.8255801065987488, 'colsample_bytree': 0.6449137749782148}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:58:02,227] Trial 71 finished with value: 0.6986011376941419 and parameters: {'scale_pos_weight': 2.626352918819697, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02141296438579455, 'subsample': 0.8600768082199195, 'colsample_bytree': 0.6405292399132722}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:58:20,103] Trial 72 finished with value: 0.6982608784363146 and parameters: {'scale_pos_weight': 2.743668332722045, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.01880149038662681, 'subsample': 0.8927133546232078, 'colsample_bytree': 0.6003602934451994}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:58:31,834] Trial 73 finished with value: 0.6983604113526335 and parameters: {'scale_pos_weight': 2.3252389661951067, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.025114586094045037, 'subsample': 0.8055206556135212, 'colsample_bytree': 0.6603901585089537}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:58:46,620] Trial 74 finished with value: 0.6983239910886612 and parameters: {'scale_pos_weight': 2.972879007711751, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.020505237093620263, 'subsample': 0.8678253372478976, 'colsample_bytree': 0.6222757760303456}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:58:56,393] Trial 75 finished with value: 0.6983974548180863 and parameters: {'scale_pos_weight': 3.6478448180008365, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.03739254172233754, 'subsample': 0.9230900950906058, 'colsample_bytree': 0.6492330521502878}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:59:14,125] Trial 76 finished with value: 0.6982868870409371 and parameters: {'scale_pos_weight': 2.543330791500091, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.015557978220716268, 'subsample': 0.853124745273076, 'colsample_bytree': 0.682558426663936}. Best is trial 51 with value: 0.6990745698896713.
# [I 2024-10-26 15:59:25,394] Trial 77 finished with value: 0.6992122244696705 and parameters: {'scale_pos_weight': 6.48662805700743, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.029653085006555918, 'subsample': 0.8353372045554543, 'colsample_bytree': 0.6403372516417984}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 15:59:34,931] Trial 78 finished with value: 0.6982216706133862 and parameters: {'scale_pos_weight': 6.10418298868142, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.04154150301076834, 'subsample': 0.8354600087499872, 'colsample_bytree': 0.6720031233346679}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 15:59:46,191] Trial 79 finished with value: 0.6978971738213587 and parameters: {'scale_pos_weight': 7.316295532401211, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.029134010257127106, 'subsample': 0.8250964394430723, 'colsample_bytree': 0.6100230405029406}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:00:11,982] Trial 80 finished with value: 0.6989372684204819 and parameters: {'scale_pos_weight': 7.199423669294741, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.013454894649271725, 'subsample': 0.7927052994606356, 'colsample_bytree': 0.6227770241532883}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:00:37,376] Trial 81 finished with value: 0.6987160787316982 and parameters: {'scale_pos_weight': 6.96411607033715, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.012760307940267824, 'subsample': 0.7947127770088074, 'colsample_bytree': 0.6282651652890808}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:00:51,595] Trial 82 finished with value: 0.6984395094049738 and parameters: {'scale_pos_weight': 6.559822151913581, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.02479444132318572, 'subsample': 0.8794822276531977, 'colsample_bytree': 0.6592786102199109}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:01:12,260] Trial 83 finished with value: 0.6987625461420031 and parameters: {'scale_pos_weight': 7.096813646663124, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.016521123576372424, 'subsample': 0.8134881518239685, 'colsample_bytree': 0.6367371233273795}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:01:34,499] Trial 84 finished with value: 0.6985417080255987 and parameters: {'scale_pos_weight': 7.123193792719544, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.012588093192115256, 'subsample': 0.8120855213756116, 'colsample_bytree': 0.609038915128157}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:01:54,009] Trial 85 finished with value: 0.6986552781759044 and parameters: {'scale_pos_weight': 6.723958851809689, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.016651323349445447, 'subsample': 0.7958384692058211, 'colsample_bytree': 0.6206913573497446}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:02:07,759] Trial 86 finished with value: 0.6962190913481484 and parameters: {'scale_pos_weight': 7.539292427989313, 'max_depth': 8, 'min_child_weight': 5, 'eta': 0.019158681430868216, 'subsample': 0.8465153532233296, 'colsample_bytree': 0.7071840406696277}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:02:19,380] Trial 87 finished with value: 0.6985519367382581 and parameters: {'scale_pos_weight': 6.5529920572908456, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.032695578349499495, 'subsample': 0.8217978172315399, 'colsample_bytree': 0.6543003776935339}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:02:27,634] Trial 88 finished with value: 0.6984409552229564 and parameters: {'scale_pos_weight': 7.238783403498174, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.05100787683318515, 'subsample': 0.7846623380222439, 'colsample_bytree': 0.6299198286796847}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:02:49,996] Trial 89 finished with value: 0.6976479950144764 and parameters: {'scale_pos_weight': 7.004966997514564, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.01366693034890705, 'subsample': 0.8324073551893315, 'colsample_bytree': 0.9915753375306281}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:03:00,035] Trial 90 finished with value: 0.6982274567225906 and parameters: {'scale_pos_weight': 4.1400644118806245, 'max_depth': 6, 'min_child_weight': 5, 'eta': 0.027197638511498888, 'subsample': 0.801174437491257, 'colsample_bytree': 0.6073582424877477}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:03:16,275] Trial 91 finished with value: 0.6981561679349005 and parameters: {'scale_pos_weight': 7.498801919710499, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02349590244150682, 'subsample': 0.8658854215390691, 'colsample_bytree': 0.6390856544923474}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:03:31,589] Trial 92 finished with value: 0.6986523647125732 and parameters: {'scale_pos_weight': 5.204429953643572, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.019951657464210598, 'subsample': 0.8438216371495069, 'colsample_bytree': 0.6215754832349563}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:03:48,383] Trial 93 finished with value: 0.6985146797603492 and parameters: {'scale_pos_weight': 6.26361438203313, 'max_depth': 5, 'min_child_weight': 5, 'eta': 0.016587100055277672, 'subsample': 0.8103544847857782, 'colsample_bytree': 0.6353632345445531}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:04:03,064] Trial 94 finished with value: 0.6991232142097005 and parameters: {'scale_pos_weight': 3.9105255208613423, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02291637336300162, 'subsample': 0.7548117302137817, 'colsample_bytree': 0.6460237664120971}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:04:27,130] Trial 95 finished with value: 0.6991604519534849 and parameters: {'scale_pos_weight': 3.897819664188607, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.011998804203927974, 'subsample': 0.7549675531491163, 'colsample_bytree': 0.6520172101180577}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:04:54,800] Trial 96 finished with value: 0.6989569350733791 and parameters: {'scale_pos_weight': 3.8778831650807426, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.010670742383184686, 'subsample': 0.7314512105838041, 'colsample_bytree': 0.6639071749948655}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:05:11,850] Trial 97 finished with value: 0.6990371234530729 and parameters: {'scale_pos_weight': 3.9149615328085523, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.018254554740249652, 'subsample': 0.7343803156670089, 'colsample_bytree': 0.6755628482296144}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:05:35,951] Trial 98 finished with value: 0.6988680888147168 and parameters: {'scale_pos_weight': 3.767960035173565, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.011369390533739015, 'subsample': 0.754008972292291, 'colsample_bytree': 0.6727102241788828}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:05:57,090] Trial 99 finished with value: 0.6989577392910619 and parameters: {'scale_pos_weight': 3.918839256717818, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.01422596197155054, 'subsample': 0.7375955177772048, 'colsample_bytree': 0.688674708699774}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:06:24,898] Trial 100 finished with value: 0.6988994070717318 and parameters: {'scale_pos_weight': 4.097359895974936, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.010006600548075738, 'subsample': 0.7356721607850086, 'colsample_bytree': 0.7056034108461334}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:06:45,444] Trial 101 finished with value: 0.698806165919721 and parameters: {'scale_pos_weight': 3.94130273490418, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.0142569756344865, 'subsample': 0.7538007256127788, 'colsample_bytree': 0.6879998413699441}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:07:02,840] Trial 102 finished with value: 0.6988698461547355 and parameters: {'scale_pos_weight': 3.4987639585425026, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.017957370657357714, 'subsample': 0.7159726282554411, 'colsample_bytree': 0.6640785244758628}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:07:26,150] Trial 103 finished with value: 0.6988354447084827 and parameters: {'scale_pos_weight': 3.8285010376097235, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.011383249061187466, 'subsample': 0.7723262052892613, 'colsample_bytree': 0.6526705466701593}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:07:49,082] Trial 104 finished with value: 0.6991145821736785 and parameters: {'scale_pos_weight': 3.940328810320109, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.015048668040266923, 'subsample': 0.7469236237259657, 'colsample_bytree': 0.6819692965418254}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:08:09,551] Trial 105 finished with value: 0.6984197862165157 and parameters: {'scale_pos_weight': 3.9589248608816052, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.014937430214507389, 'subsample': 0.6924017153559442, 'colsample_bytree': 0.6769801798465934}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:08:25,446] Trial 106 finished with value: 0.6988815686237252 and parameters: {'scale_pos_weight': 4.412885504148408, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.0205483562479293, 'subsample': 0.7280630168721872, 'colsample_bytree': 0.7293333564215485}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:08:37,856] Trial 107 finished with value: 0.6991628502968167 and parameters: {'scale_pos_weight': 4.204741703985879, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.026808164989441337, 'subsample': 0.7440984426187177, 'colsample_bytree': 0.6871427252785279}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:08:50,134] Trial 108 finished with value: 0.6985749270894841 and parameters: {'scale_pos_weight': 4.717462243053752, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02364283702966547, 'subsample': 0.7458003457527475, 'colsample_bytree': 0.7023877840748781}. Best is trial 77 with value: 0.6992122244696705.
# [I 2024-10-26 16:09:04,373] Trial 109 finished with value: 0.6993637683384356 and parameters: {'scale_pos_weight': 4.185330400898334, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.026795630994105812, 'subsample': 0.7357274176530111, 'colsample_bytree': 0.690764467951427}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:09:16,742] Trial 110 finished with value: 0.6983358896157954 and parameters: {'scale_pos_weight': 4.185694095324162, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.027029680985691373, 'subsample': 0.7240169346268988, 'colsample_bytree': 0.6892641258895107}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:09:30,180] Trial 111 finished with value: 0.6992283558966857 and parameters: {'scale_pos_weight': 4.1015819529618796, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02982069203145913, 'subsample': 0.7342404089840459, 'colsample_bytree': 0.7185596927762539}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:09:42,078] Trial 112 finished with value: 0.6990157017611643 and parameters: {'scale_pos_weight': 4.052935213495252, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.030533080394467095, 'subsample': 0.7355503572064173, 'colsample_bytree': 0.7176921592415393}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:09:53,179] Trial 113 finished with value: 0.6989116122614831 and parameters: {'scale_pos_weight': 4.059826068574354, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.03149527433392217, 'subsample': 0.7404328681262787, 'colsample_bytree': 0.7421019296686594}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:10:06,121] Trial 114 finished with value: 0.6993426170058198 and parameters: {'scale_pos_weight': 3.704588154851348, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.0284825829439093, 'subsample': 0.7644925315421646, 'colsample_bytree': 0.7143014251277799}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:10:18,212] Trial 115 finished with value: 0.6992759856989489 and parameters: {'scale_pos_weight': 4.490518561966568, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02920408294619866, 'subsample': 0.764175930084422, 'colsample_bytree': 0.6993026776476514}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:10:30,928] Trial 116 finished with value: 0.6983867713904245 and parameters: {'scale_pos_weight': 4.34104474131316, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.036315806343308374, 'subsample': 0.7518392692028373, 'colsample_bytree': 0.6987356883561949}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:10:42,878] Trial 117 finished with value: 0.6989212243693074 and parameters: {'scale_pos_weight': 4.530877847769945, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.028814936035788174, 'subsample': 0.7661089170307906, 'colsample_bytree': 0.7255978163611457}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:10:54,814] Trial 118 finished with value: 0.6986403138046949 and parameters: {'scale_pos_weight': 3.654092908504569, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.0334956074493076, 'subsample': 0.761974474048728, 'colsample_bytree': 0.6949724702916515}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:11:07,283] Trial 119 finished with value: 0.6986202692548842 and parameters: {'scale_pos_weight': 4.450621766641508, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02660010777399778, 'subsample': 0.778717656773961, 'colsample_bytree': 0.7381177101467309}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:11:23,372] Trial 120 finished with value: 0.698632590656768 and parameters: {'scale_pos_weight': 3.7523570492632468, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.022952515531405492, 'subsample': 0.7124331417313049, 'colsample_bytree': 0.6810163474707361}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:11:36,085] Trial 121 finished with value: 0.6990667273090531 and parameters: {'scale_pos_weight': 4.228445955214703, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.03086778661847521, 'subsample': 0.7475507536259567, 'colsample_bytree': 0.7187264872387606}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:11:49,189] Trial 122 finished with value: 0.6989332360566379 and parameters: {'scale_pos_weight': 4.205098471988469, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02889194488612395, 'subsample': 0.7504646364020829, 'colsample_bytree': 0.7048932137260516}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:12:02,979] Trial 123 finished with value: 0.6988570413584143 and parameters: {'scale_pos_weight': 3.4455624813529635, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.0350871896900879, 'subsample': 0.7686845253568625, 'colsample_bytree': 0.7193638762788199}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:12:13,353] Trial 124 finished with value: 0.6985228486672975 and parameters: {'scale_pos_weight': 4.313097926609427, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.040821442023059776, 'subsample': 0.7589421585559429, 'colsample_bytree': 0.7117598997346658}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:12:25,588] Trial 125 finished with value: 0.6984915684755052 and parameters: {'scale_pos_weight': 4.15082782272003, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.03202728223467243, 'subsample': 0.7204535264061417, 'colsample_bytree': 0.772513764783062}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:12:40,024] Trial 126 finished with value: 0.6988761094486408 and parameters: {'scale_pos_weight': 4.679726799200564, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.025831590008724727, 'subsample': 0.745558338402888, 'colsample_bytree': 0.7493003431981574}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:12:56,557] Trial 127 finished with value: 0.6985267843791304 and parameters: {'scale_pos_weight': 3.5801640678207343, 'max_depth': 5, 'min_child_weight': 4, 'eta': 0.02485439993051094, 'subsample': 0.7066498400986944, 'colsample_bytree': 0.7911846267622045}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:13:10,842] Trial 128 finished with value: 0.6990333486507158 and parameters: {'scale_pos_weight': 3.697021152655777, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.028544673548398104, 'subsample': 0.77456173494167, 'colsample_bytree': 0.6746217786179848}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:13:23,418] Trial 129 finished with value: 0.6990314428100676 and parameters: {'scale_pos_weight': 4.021238738143415, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.02920772959689301, 'subsample': 0.7761552407276475, 'colsample_bytree': 0.6749082763526633}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:13:36,605] Trial 130 finished with value: 0.6991458350763305 and parameters: {'scale_pos_weight': 3.7927946254440625, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.02749362352879888, 'subsample': 0.757087306055512, 'colsample_bytree': 0.6812765452922619}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:13:48,994] Trial 131 finished with value: 0.6992636628155355 and parameters: {'scale_pos_weight': 3.694049486813377, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.028513496577017475, 'subsample': 0.7619948496831681, 'colsample_bytree': 0.6811102224535056}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:14:01,456] Trial 132 finished with value: 0.699316904602056 and parameters: {'scale_pos_weight': 3.7693513710977378, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.03221629168383859, 'subsample': 0.7608172143719357, 'colsample_bytree': 0.6964770523400446}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:14:13,715] Trial 133 finished with value: 0.6988839709211009 and parameters: {'scale_pos_weight': 3.7665524327578215, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.03060323971158415, 'subsample': 0.7642139314575261, 'colsample_bytree': 0.7123483136149662}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:14:23,875] Trial 134 finished with value: 0.6959263026647479 and parameters: {'scale_pos_weight': 4.232674859503539, 'max_depth': 8, 'min_child_weight': 3, 'eta': 0.0340283547920311, 'subsample': 0.7576810342951572, 'colsample_bytree': 0.6976091162806988}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:14:37,943] Trial 135 finished with value: 0.699354828621892 and parameters: {'scale_pos_weight': 3.821662186016139, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.036570772656913345, 'subsample': 0.7448506269337849, 'colsample_bytree': 0.6855602542280334}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:14:47,481] Trial 136 finished with value: 0.698565166870608 and parameters: {'scale_pos_weight': 3.4279127642661456, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.038673206555821384, 'subsample': 0.7853967379506838, 'colsample_bytree': 0.6850199626715535}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:14:59,208] Trial 137 finished with value: 0.6992158571388943 and parameters: {'scale_pos_weight': 3.8192690132505773, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.033002451702262105, 'subsample': 0.744396948873009, 'colsample_bytree': 0.6910100042055515}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:15:07,195] Trial 138 finished with value: 0.6960898973990884 and parameters: {'scale_pos_weight': 3.816836871329778, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.0363514558632366, 'subsample': 0.7444455055205751, 'colsample_bytree': 0.6901921789401414}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:15:18,952] Trial 139 finished with value: 0.6986458211571384 and parameters: {'scale_pos_weight': 3.683742562760626, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.032801459021751314, 'subsample': 0.7252503979913467, 'colsample_bytree': 0.6831216075673326}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:15:30,998] Trial 140 finished with value: 0.6970635047683532 and parameters: {'scale_pos_weight': 3.320791975949745, 'max_depth': 7, 'min_child_weight': 3, 'eta': 0.02729706580813556, 'subsample': 0.7557838197335942, 'colsample_bytree': 0.6656911529636756}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:15:45,678] Trial 141 finished with value: 0.6988596035732609 and parameters: {'scale_pos_weight': 4.009258385194101, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.025666972838778827, 'subsample': 0.7688554172560174, 'colsample_bytree': 0.699634168007305}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:15:59,936] Trial 142 finished with value: 0.6991879313845059 and parameters: {'scale_pos_weight': 3.5645737558522343, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.02394283635090092, 'subsample': 0.7411898527778473, 'colsample_bytree': 0.6469284051108647}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:16:11,432] Trial 143 finished with value: 0.6992739036341092 and parameters: {'scale_pos_weight': 3.5557839750418325, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.029052744066323286, 'subsample': 0.751162830010859, 'colsample_bytree': 0.6495105603583355}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:16:22,589] Trial 144 finished with value: 0.6989862053422997 and parameters: {'scale_pos_weight': 3.572095930493583, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.0319672834001569, 'subsample': 0.7305500383390772, 'colsample_bytree': 0.6587491807915439}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:16:35,724] Trial 145 finished with value: 0.6990241855328666 and parameters: {'scale_pos_weight': 3.12578052421747, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.027414215747092397, 'subsample': 0.7619813966642743, 'colsample_bytree': 0.6511986752471383}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:16:47,079] Trial 146 finished with value: 0.6987652125750393 and parameters: {'scale_pos_weight': 3.821813822119971, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0.03525497012134659, 'subsample': 0.7386000335839427, 'colsample_bytree': 0.6463827381284585}. Best is trial 109 with value: 0.6993637683384356.
# [I 2024-10-26 16:17:02,575] Trial 147 finished with value: 0.6991509538359031 and parameters: {'scale_pos_weight': 5.8525804940195245, 'max_depth': 5, 'min_child_weight': 3, 'eta': 0
# [357]	train-aucpr:0.71252	eval-aucpr:0.68946
# [358]	train-aucpr:0.71252	eval-aucpr:0.68942
# [359]	train-aucpr:0.71261	eval-aucpr:0.68940
# [360]	train-aucpr:0.71264	eval-aucpr:0.68938
# [361]	train-aucpr:0.71265	eval-aucpr:0.68933
# [362]	train-aucpr:0.71267	eval-aucpr:0.68933
# [363]	train-aucpr:0.71268	eval-aucpr:0.68934
# [364]	train-aucpr:0.71260	eval-aucpr:0.68931
# [365]	train-aucpr:0.71265	eval-aucpr:0.68936
# [366]	train-aucpr:0.71278	eval-aucpr:0.68934
# [367]	train-aucpr:0.71279	eval-aucpr:0.68934
# [368]	train-aucpr:0.71281	eval-aucpr:0.68934
# [369]	train-aucpr:0.71287	eval-aucpr:0.68933
# [370]	train-aucpr:0.71284	eval-aucpr:0.68937
# [371]	train-aucpr:0.71283	eval-aucpr:0.68920
# [372]	train-aucpr:0.71284	eval-aucpr:0.68920
# [373]	train-aucpr:0.71292	eval-aucpr:0.68920
# [374]	train-aucpr:0.71291	eval-aucpr:0.68904
# [375]	train-aucpr:0.71296	eval-aucpr:0.68905
# [376]	train-aucpr:0.71311	eval-aucpr:0.68928
# [377]	train-aucpr:0.71313	eval-aucpr:0.68934
# [378]	train-aucpr:0.71315	eval-aucpr:0.68922
# [379]	train-aucpr:0.71316	eval-aucpr:0.68923
# [380]	train-aucpr:0.71317	eval-aucpr:0.68924
# [381]	train-aucpr:0.71319	eval-aucpr:0.68922
# [382]	train-aucpr:0.71321	eval-aucpr:0.68925
# [383]	train-aucpr:0.71321	eval-aucpr:0.68920
# [384]	train-aucpr:0.71323	eval-aucpr:0.68916
# [385]	train-aucpr:0.71324	eval-aucpr:0.68912
# [386]	train-aucpr:0.71327	eval-aucpr:0.68910
# [387]	train-aucpr:0.71329	eval-aucpr:0.68900
# [388]	train-aucpr:0.71330	eval-aucpr:0.68899
# [389]	train-aucpr:0.71337	eval-aucpr:0.68905
# [390]	train-aucpr:0.71339	eval-aucpr:0.68905
# [391]	train-aucpr:0.71341	eval-aucpr:0.68904
# [392]	train-aucpr:0.71345	eval-aucpr:0.68898
# [393]	train-aucpr:0.71347	eval-aucpr:0.68895
# [394]	train-aucpr:0.71345	eval-aucpr:0.68887
# [395]	train-aucpr:0.71350	eval-aucpr:0.68890
# [396]	train-aucpr:0.71351	eval-aucpr:0.68887
# [397]	train-aucpr:0.71354	eval-aucpr:0.68888
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.67      0.79     11360
#            1       0.47      0.91      0.62      3700
#
#     accuracy                           0.73     15060
#    macro avg       0.71      0.79      0.70     15060
# weighted avg       0.84      0.73      0.75     15060
#
# ROC-AUC Score:
# 0.8764740078987439
# PR AUC Score:
# 0.6872871514561442
# Total time taken: 6019.64 seconds

# %% [markdown]
# After this test we arrived to the conclusion that both methods built good models, different but close in quality. Nevertheless, one-hot encoding ended up taking more time as predicted and does take more computer capacity, this difference will be increased if there are more categorical features in our dataset. Ordinal encoding didn't show any signal of inferiority and all the signs of higher perfomance so I recommend anyone that could be reading to take a look at it!
